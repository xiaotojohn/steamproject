# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time
import tqdm

# third-party imports
import numpy as np
import pandas as pd
import requests

# %%
# # merge all the game data into one dataframe
# # leave this commented if you are using the provided anydeal.csv
# temp_df = pd.DataFrame()
# for i in range(0, 3000,10):
#     if i == 0:
#         temp_df = pd.read_csv(f"textfiles/game_info/last_successful_batch_{i}_game_info_anydeal.csv", index_col=0)
#     else:
#         temp_df = pd.concat([temp_df, pd.read_csv(f"textfiles/game_info/last_successful_batch_{i}_game_info_anydeal.csv", index_col=0)])
# temp_df.to_csv('anydeal.csv')

# %%
# # merge all the game prices into one dataframe
# temp_df = pd.DataFrame()
# for i in range(0, 3000,10):
#     if i == 0:
#         temp_df = pd.read_csv(f"textfiles/price_history/last_successful_batch_{i}_price_history.csv", index_col=0)
#     else:
#         temp_df = pd.concat([temp_df, pd.read_csv(f"textfiles/price_history/last_successful_batch_{i}_price_history.csv", index_col=0)])

# temp_df.to_csv('anydeal_prices.csv')

# %%
df_game_info = pd.read_csv('anydeal.csv')
df_price_history = pd.read_csv('anydeal_prices.csv')
df_price_history.rename(columns={'appid':'id'}, inplace=True)

# %%
df_game_info[df_game_info['id'] == '018d937f-1569-701c-bf2f-21163ded8f02']
# Out:
#                                        id                slug  \
# 299  018d937f-1569-701c-bf2f-21163ded8f02  total-war-shogun-2
# 383  018d937f-1569-701c-bf2f-21163ded8f02  total-war-shogun-2
#
#                    title  type  mature  \
# 299  Total War SHOGUN™ 2  game   False
# 383  Total War SHOGUN™ 2  game   False
#
#                                                 assets  earlyAccess  \
# 299  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 383  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
#
#      achievements  tradingCards     appid  \
# 299          True          True  201270.0
# 383          True          True  201270.0
#
#                                                   tags releaseDate  \
# 299  ['Strategy', 'Historical', 'Turn-Based Strateg...  2011-03-14
# 383  ['Strategy', 'Historical', 'Turn-Based Strateg...  2011-03-14
#
#                                             developers  \
# 299  [{'id': 466, 'name': 'Creative Assembly'}, {'i...
# 383  [{'id': 466, 'name': 'Creative Assembly'}, {'i...
#
#                                             publishers  \
# 299  [{'id': 95, 'name': 'SEGA'}, {'id': 5464, 'nam...
# 383  [{'id': 95, 'name': 'SEGA'}, {'id': 5464, 'nam...
#
#                                                reviews  \
# 299  [{'score': 90, 'source': 'Metascore', 'count':...
# 383  [{'score': 90, 'source': 'Metascore', 'count':...
#
#                                                  stats  \
# 299  {'rank': 154, 'waitlisted': 1524, 'collected':...
# 383  {'rank': 154, 'waitlisted': 1524, 'collected':...
#
#                                              players  \
# 299  {'recent': 0, 'day': 1, 'week': 2, 'peak': 122}
# 383  {'recent': 0, 'day': 1, 'week': 2, 'peak': 122}
#
#                                                   urls
# 299  {'game': 'https://isthereanydeal.com/game/tota...
# 383  {'game': 'https://isthereanydeal.com/game/tota...

# %%
# check for duplicates
df_game_info[df_game_info.duplicated('id')]
# Out:
#                                         id  \
# 383   018d937f-1569-701c-bf2f-21163ded8f02
# 1220  018d937f-269a-71ef-ae12-7e4d194b3514
# 1670  018d937e-fdec-7040-bb13-3d96b353c3c0
# 1939  018d937f-0896-71b1-94d9-82725d1e320a
# 2453  018d937f-0a68-709b-bcc7-4d842e4fe130
#
#                                        slug  \
# 383                      total-war-shogun-2
# 1220           poker-night-at-the-inventory
# 1670              wasteland-2-directors-cut
# 1939                      fallout-new-vegas
# 2453  space-hulk-deathwing-enhanced-edition
#
#                                          title  type  mature  \
# 383                        Total War SHOGUN™ 2  game   False
# 1220              Poker Night at the Inventory   NaN   False
# 1670               Wasteland 2: Director's Cut  game   False
# 1939                      Fallout®: New Vegas™  game   False
# 2453  Space Hulk: Deathwing - Enhanced Edition  game   False
#
#                                                  assets  earlyAccess  \
# 383   {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 1220                                                 []        False
# 1670  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 1939  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2453  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
#
#       achievements  tradingCards     appid  \
# 383           True          True  201270.0
# 1220         False         False       NaN
# 1670          True         False  240760.0
# 1939          True         False   22380.0
# 2453          True         False  816090.0
#
#                                                    tags releaseDate  \
# 383   ['Strategy', 'Historical', 'Turn-Based Strateg...  2011-03-14
# 1220                                                 []         NaN
# 1670  ['RPG', 'Post-apocalyptic', 'Turn-Based', 'Str...  2014-09-19
# 1939  ['Open World', 'RPG', 'Post-apocalyptic', 'Sin...  2010-10-19
# 2453  ['Action', 'Warhammer 40K', 'Co-op', 'FPS', 'S...  2018-05-22
#
#                                              developers  \
# 383   [{'id': 466, 'name': 'Creative Assembly'}, {'i...
# 1220                                                 []
# 1670      [{'id': 807, 'name': 'inXile Entertainment'}]
# 1939    [{'id': 656, 'name': 'Obsidian Entertainment'}]
# 2453         [{'id': 1633, 'name': 'Streum On Studio'}]
#
#                                              publishers  \
# 383   [{'id': 95, 'name': 'SEGA'}, {'id': 5464, 'nam...
# 1220                                                 []
# 1670  [{'id': 807, 'name': 'inXile Entertainment'}, ...
# 1939  [{'id': 18, 'name': 'Bethesda Softworks'}, {'i...
# 2453  [{'id': 106, 'name': 'Focus Entertainment'}, {...
#
#                                                 reviews  \
# 383   [{'score': 90, 'source': 'Metascore', 'count':...
# 1220  [{'score': 71, 'source': 'Metascore', 'count':...
# 1670  [{'score': 82, 'source': 'Steam', 'count': 460...
# 1939  [{'score': 96, 'source': 'Steam', 'count': 170...
# 2453  [{'score': 71, 'source': 'Steam', 'count': 757...
#
#                                                   stats  \
# 383   {'rank': 154, 'waitlisted': 1524, 'collected':...
# 1220  {'rank': 553, 'waitlisted': 381, 'collected': ...
# 1670  {'rank': 303, 'waitlisted': 5029, 'collected':...
# 1939  {'rank': 31, 'waitlisted': 4053, 'collected': ...
# 2453  {'rank': 3213, 'waitlisted': 2661, 'collected'...
#
#                                                 players  \
# 383     {'recent': 0, 'day': 1, 'week': 2, 'peak': 122}
# 1220                                                NaN
# 1670  {'recent': 15, 'day': 16, 'week': 19, 'peak': ...
# 1939  {'recent': 5289, 'day': 5289, 'week': 5732, 'p...
# 2453  {'recent': 53, 'day': 87, 'week': 89, 'peak': ...
#
#                                                    urls
# 383   {'game': 'https://isthereanydeal.com/game/tota...
# 1220  {'game': 'https://isthereanydeal.com/game/poke...
# 1670  {'game': 'https://isthereanydeal.com/game/wast...
# 1939  {'game': 'https://isthereanydeal.com/game/fall...
# 2453  {'game': 'https://isthereanydeal.com/game/spac...

# %%
# check for duplicates
df_price_history[df_price_history.duplicated('id')]
# Out:
#                                         id  \
# 383   018d937f-1569-701c-bf2f-21163ded8f02
# 1220  018d937f-269a-71ef-ae12-7e4d194b3514
# 1670  018d937e-fdec-7040-bb13-3d96b353c3c0
# 1939  018d937f-0896-71b1-94d9-82725d1e320a
# 2453  018d937f-0a68-709b-bcc7-4d842e4fe130
#
#                                           price_history
# 383   [{'timestamp': '2024-07-11T19:18:56+02:00', 's...
# 1220  [{'timestamp': '2018-07-24T22:22:11+02:00', 's...
# 1670  [{'timestamp': '2024-07-11T19:19:14+02:00', 's...
# 1939  [{'timestamp': '2024-07-11T19:18:39+02:00', 's...
# 2453  [{'timestamp': '2024-07-25T19:16:14+02:00', 's...

# %%
# remove duplicates before merging
# The duplicates are caused by the different data collection method used for steamspy and ITAD
# Steamspy used the appid from steam, which led to duplicates for different reasons, such as:
# Fallout: New Vegas has two appids on steam, one for international and one for russian version
# Total War: Shogun 2 has two appids on steam, but both lead to the same game page
# ITAD used their own unique id, which is unique for each game
# As we only use steamspy data for ranking, we will remove the duplicates from the steamspy data
# and keep the ITAD data for the duplicates

df_game_info.drop_duplicates('id', inplace=True)
df_price_history.drop_duplicates('id', inplace=True)
# merge the two dataframes

df = pd.merge(df_game_info, df_price_history, on='id', how='inner')

# %%
df_without_history = df[df['price_history'] == '[]']
df_without_history.to_csv('anydeal_without_history.csv')

# %%
# remove rows without price history
df.drop(df[df['price_history'] == '[]'].index, inplace=True)

# %%
df
# Out:
#                                         id                       slug  \
# 0     018d937f-19a5-7057-bb6d-314d586e6dbc                     dota-2
# 1     018d937f-7851-7004-b780-3f657a301f9a           counter-strike-2
# 2     018d937f-57ce-723f-b7e7-7c7b5df93471         pubg-battlegrounds
# 3     018d937f-50c1-7086-807c-e020c98c72b2                   palworld
# 4     018d937e-fde4-72ff-a7af-45e4955a8dd6            team-fortress-2
# ...                                    ...                        ...
# 2989  018d937e-f973-71db-988b-4b9d2c183d55  battlefleet-gothic-armada
# 2990  018d96f1-a1a9-70ec-9c8a-06ef9eb86465  occupy-mars-prologue-2020
# 2991  018d979a-4ad7-71e4-aecc-eb83bede66c6           fiesta-online--1
# 2992  018d937f-33c1-70d1-b6c0-2e871940149a     scythe-digital-edition
# 2993  018d937f-0e8d-7115-aaf8-578876bc1c80             wanba-warriors
#
#                              title  type  mature  \
# 0                           Dota 2  game   False
# 1                 Counter-Strike 2  game   False
# 2              PUBG: BATTLEGROUNDS  game   False
# 3                         Palworld  game   False
# 4                  Team Fortress 2  game   False
# ...                            ...   ...     ...
# 2989    Battlefleet Gothic: Armada  game   False
# 2990  Occupy Mars: Prologue (2020)  game   False
# 2991                 Fiesta Online  game   False
# 2992       Scythe: Digital Edition  game   False
# 2993                Wanba Warriors  game   False
#
#                                                  assets  earlyAccess  \
# 0     {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 1     {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2     {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 3     {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 4     {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# ...                                                 ...          ...
# 2989  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2990  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2991  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2992  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
# 2993  {'boxart': 'https://dbxce1spal1df.cloudfront.n...        False
#
#       achievements  tradingCards      appid  \
# 0            False          True      570.0
# 1            False          True      730.0
# 2             True         False   578080.0
# 3             True         False  1623730.0
# 4             True          True      440.0
# ...            ...           ...        ...
# 2989          True          True   363680.0
# 2990         False         False  1310520.0
# 2991         False         False   300970.0
# 2992          True          True   718560.0
# 2993         False          True  1021770.0
#
#                                                    tags releaseDate  \
# 0     ['Free to Play', 'MOBA', 'Multiplayer', 'Strat...  2013-07-09
# 1     ['FPS', 'Shooter', 'Multiplayer', 'Competitive...  2012-08-21
# 2     ['Survival', 'Shooter', 'Battle Royale', 'Mult...  2017-12-21
# 3     ['Open World', 'Multiplayer', 'Survival', 'Cre...  2024-01-19
# 4     ['Free to Play', 'Hero Shooter', 'Multiplayer'...  2007-10-10
# ...                                                 ...         ...
# 2989  ['Strategy', 'Warhammer 40K', 'Space', 'RTS', ...  2016-04-01
# 2990  ['Open World Survival Craft', 'Survival', 'Ope...  2020-08-20
# 2991  ['Free to Play', 'Massively Multiplayer', 'Ani...  2014-05-21
# 2992  ['Board Game', 'Strategy', 'Turn-Based', 'Mult...  2018-09-05
# 2993  ['Fighting', 'Multiplayer', 'Funny', 'Parody '...  2020-03-25
#
#                                          developers  \
# 0                   [{'id': 5445, 'name': 'Valve'}]
# 1                   [{'id': 5445, 'name': 'Valve'}]
# 2          [{'id': 13154, 'name': 'KRAFTON, Inc.'}]
# 3             [{'id': 29012, 'name': 'Pocketpair'}]
# 4                   [{'id': 5445, 'name': 'Valve'}]
# ...                                             ...
# 2989  [{'id': 910, 'name': 'Tindalos Interactive'}]
# 2990        [{'id': 8870, 'name': 'Pyramid Games'}]
# 2991            [{'id': 7131, 'name': 'gamigo AG'}]
# 2992  [{'id': 940, 'name': 'The Knights of Unity'}]
# 2993         [{'id': 1879, 'name': 'Wanba Studio'}]
#
#                                              publishers  \
# 0                       [{'id': 5445, 'name': 'Valve'}]
# 1                       [{'id': 5445, 'name': 'Valve'}]
# 2              [{'id': 13154, 'name': 'KRAFTON, Inc.'}]
# 3                 [{'id': 29012, 'name': 'Pocketpair'}]
# 4                       [{'id': 5445, 'name': 'Valve'}]
# ...                                                 ...
# 2989  [{'id': 106, 'name': 'Focus Entertainment'}, {...
# 2990      [{'id': 10811, 'name': 'Pyramid Games S.A.'}]
# 2991                [{'id': 7131, 'name': 'gamigo AG'}]
# 2992  [{'id': 1105, 'name': 'Asmodee Digital'}, {'id...
# 2993             [{'id': 1879, 'name': 'Wanba Studio'}]
#
#                                                 reviews  \
# 0     [{'score': 81, 'source': 'Steam', 'count': 227...
# 1     [{'score': 87, 'source': 'Steam', 'count': 814...
# 2     [{'score': 58, 'source': 'Steam', 'count': 239...
# 3     [{'score': 93, 'source': 'Steam', 'count': 268...
# 4     [{'score': 86, 'source': 'Steam', 'count': 111...
# ...                                                 ...
# 2989  [{'score': 68, 'source': 'Steam', 'count': 479...
# 2990  [{'score': 78, 'source': 'Steam', 'count': 153...
# 2991  [{'score': 60, 'source': 'Steam', 'count': 733...
# 2992  [{'score': 90, 'source': 'Steam', 'count': 286...
# 2993  [{'score': 91, 'source': 'Steam', 'count': 219...
#
#                                                   stats  \
# 0     {'rank': 645, 'waitlisted': 100, 'collected': ...
# 1     {'rank': 519, 'waitlisted': 238, 'collected': ...
# 2     {'rank': 1682, 'waitlisted': 959, 'collected':...
# 3     {'rank': 415, 'waitlisted': 10630, 'collected'...
# 4     {'rank': 454, 'waitlisted': 18, 'collected': 2...
# ...                                                 ...
# 2989  {'rank': 3333, 'waitlisted': 2815, 'collected'...
# 2990  {'rank': 24532, 'waitlisted': 99, 'collected':...
# 2991  {'rank': 23171, 'waitlisted': 14, 'collected':...
# 2992  {'rank': 3241, 'waitlisted': 2238, 'collected'...
# 2993  {'rank': 8208, 'waitlisted': 310, 'collected':...
#
#                                                 players  \
# 0     {'recent': 508811, 'day': 689869, 'week': 7566...
# 1     {'recent': 940515, 'day': 1268934, 'week': 134...
# 2     {'recent': 372658, 'day': 613911, 'week': 6695...
# 3     {'recent': 38763, 'day': 46359, 'week': 59456,...
# 4     {'recent': 69106, 'day': 82557, 'week': 97322,...
# ...                                                 ...
# 2989  {'recent': 26, 'day': 47, 'week': 47, 'peak': ...
# 2990   {'recent': 5, 'day': 7, 'week': 11, 'peak': 235}
# 2991  {'recent': 37, 'day': 37, 'week': 45, 'peak': 71}
# 2992  {'recent': 76, 'day': 84, 'week': 84, 'peak': ...
# 2993  {'recent': 13, 'day': 43, 'week': 50, 'peak': ...
#
#                                                    urls  \
# 0     {'game': 'https://isthereanydeal.com/game/dota...
# 1     {'game': 'https://isthereanydeal.com/game/coun...
# 2     {'game': 'https://isthereanydeal.com/game/pubg...
# 3     {'game': 'https://isthereanydeal.com/game/palw...
# 4     {'game': 'https://isthereanydeal.com/game/team...
# ...                                                 ...
# 2989  {'game': 'https://isthereanydeal.com/game/batt...
# 2990  {'game': 'https://isthereanydeal.com/game/occu...
# 2991  {'game': 'https://isthereanydeal.com/game/fies...
# 2992  {'game': 'https://isthereanydeal.com/game/scyt...
# 2993  {'game': 'https://isthereanydeal.com/game/wanb...
#
#                                           price_history
# 0     [{'timestamp': '2024-02-11T01:47:46+01:00', 's...
# 1     [{'timestamp': '2024-02-11T01:47:46+01:00', 's...
# 2     [{'timestamp': '2024-02-11T03:51:23+01:00', 's...
# 3     [{'timestamp': '2024-07-18T19:16:16+02:00', 's...
# 4     [{'timestamp': '2024-02-11T01:47:46+01:00', 's...
# ...                                                 ...
# 2989  [{'timestamp': '2024-07-25T19:16:13+02:00', 's...
# 2990  [{'timestamp': '2024-02-11T08:58:04+01:00', 's...
# 2991  [{'timestamp': '2024-02-11T02:18:13+01:00', 's...
# 2992  [{'timestamp': '2024-07-22T19:16:52+02:00', 's...
# 2993  [{'timestamp': '2024-07-29T19:17:59+02:00', 's...
#
# [2966 rows x 19 columns]

# %%
# temp_ = df[df['id'] == '018d937f-0896-71b1-94d9-82725d1e320a'] # fallout new vegas
# temp_ = df[df['id'] == '018d937f-590c-728b-ac35-38bcff85f086'] # Elden Ring
# temp_ = df[df['id'] == '018d9584-24d6-7010-b82b-df1f0b154cc7'] # Baldur's Gate 3
# temp_ = df[df['id'] == '018d937f-0de8-7372-aa7a-fc902b95be0c'] # Outlast
# temp_ = df[df['id'] == '018d937f-3a94-7168-b777-3ac0398724cc'] # mi zhang sheng
# temp_ = df[df['id'] == '018d937f-209c-7223-8ead-671a11f25e7e'] # Dark Souls 3
# temp_ = df[df['id'] == '018d937f-089f-73ea-b66e-3167274fdfe7'] # Doom 3
# temp_ = df[df['id'] == '018d937f-19a5-7057-bb6d-314d586e6dbc'] # Dota 2
# temp_ = df[df['id'] == '018d937f-08bb-72d1-9a4a-d63dd4fa1df2'] # paladins # apparently if the game is free, its price history will lead to problems, we have to write a function to remove free games
# temp_ = df[df['id'] == '018d937f-57ce-723f-b7e7-7c7b5df93471'] # pubg

# %%
def handling_price_history(temp_):
    # this function will handle the price history column
    # a dataframe of the price history, based on days will be returned
    
    # # if the game is free, return an empty dataframe
    # if temp_['current_price'].iloc[0] == 0:
    #     return pd.DataFrame()
    # so I give up this idea, major reason is
    # we have games started with charge and then became free
    # for example PUBG, it was a paid game, but it became free in 2022 Jan
    # somehow, the data in isthereanydeal showed it became free in 2021 Sep


    # convert the price history from string to json
    history = temp_['price_history'].iloc[0]
    history = history.replace("'", '"')
    history = json.loads(history)

    # create the history dataframe
    history = pd.DataFrame(history)

    # convert the timestamp to datetime, keeping days only
    history['timestamp'] = pd.to_datetime(history['timestamp'],utc=True)
    history['timestamp'] = pd.to_datetime(history['timestamp'].dt.date)

    # remove the shop column, as it is the same for all rows
    history.drop(columns=['shop'], inplace=True)

    # extract the price info
    history['regular_price'] = history['deal'].apply(lambda x: x['regular']['amount'])
    history['current_price'] = history['deal'].apply(lambda x: x['price']['amount'])
    history['discount'] = history['deal'].apply(lambda x: x['cut'])

    # remove the deal column
    history.drop(columns=['deal'], inplace=True)

    # sort the dataframe by date
    history.sort_values(by='timestamp', inplace=True, ascending=True)

    return history



def daily_price_constuctor(df):
    # construct a dataframe with the every day price history based on a given date range
    # will be used to calculate the average price for each game 
    # as average price will be weighted by the number of days

    start_date = df.iloc[0]['timestamp']
    end_date = df.iloc[-1]['timestamp']
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    price_history = pd.DataFrame()
    price_history['timestamp'] = date_range
    price_history['timestamp'] = pd.to_datetime(price_history['timestamp'])
    price_history = price_history.merge(df, how='left', on='timestamp')
    price_history['timestamp'] = price_history['timestamp'].dt.date
    price_history['regular_price'].ffill(inplace=True)
    price_history['current_price'].ffill(inplace=True)
    price_history['discount'].ffill(inplace=True)

    return price_history

# test_function_var = handling_price_history(temp_)

# print(test_function_var.to_string())

# print(daily_price_constuctor(test_function_var).to_string())

# %%
price_items = {
    'first_available_price': '', # the first price of the game
    'regular_price_reduced': '', # boolean, true if the regular price has been reduced
    'price_reduced_date': '', # null if regular_price_reduced is false
    'first_available_date': '', # date of the first available price
    'last_available_date': '', # date of the last available price
    'historical_low': '', # the lowest price of the game
    'historical_low_date': '', # the date of the lowest price
    'historical_high_discount': '', # the highest discount of the game
    'historical_high_discount_date': '', # the date of the highest discount
    'first_discount': '', # the first discount of the game
    'first_discount_date': '', # the date of the first discount
    'last_discount': '', # the last discount of the game
    'last_discount_date': '', # the date of the last discount
    'discount_distribution': '', # the distribution of discounts based on months


    

    # the following modules require the daily price history
    'average_duration_between_discounts_12months': '', # the average duration between discounts in the last 12 months
    'average_duration_of_discounts_12months': '', # the average duration of discounts in the last 12 months
    'avg_price': '', # the average price of the game 
    'avg_discount': '', # the average discount of the game, calculated as the average of the discount percentage
    # time series analysis items
    'next_discount': '',
    # price decay is the average second derivative of a moving average of the price
    # we take 12 months of data, and calculate the moving average of the price
    # then we calculate the second derivative of the moving average
    # finally we average the second derivative over the 12 months
    'price_decay_rate': ''

}

price_items_names = list(price_items.keys())

def calculate_price_items(temp_):
    temp_ = temp_.to_frame().T
    print('now processing:', temp_['title'].iloc[0])
    history = handling_price_history(temp_)


    # calculate the items

    first_available_price = history['regular_price'].iloc[0]
    if first_available_price == 0:
        # if the game started as free, return an empty dictionary
        return [None for i in range(len(price_items_names))]
    
    # if the regular price has been reduced
    if history['regular_price'].unique().shape[0] > 1:
        prices = history['regular_price'].unique()
        # print(prices)
        regular_price_reduced = True
        # find the date when the price was reduced
        price_reduced_date = history[history['regular_price'] == prices[1]]['timestamp'].iloc[0]
    else:
        regular_price_reduced = False
        price_reduced_date = None

    first_available_date = history['timestamp'].iloc[0]

    last_available_date = history['timestamp'].iloc[-1]

    historical_low = history['current_price'].min()

    if historical_low == first_available_price:
        historical_low_date = None
    else:
        historical_low_date = history[history['current_price'] == historical_low]['timestamp'].iloc[0]

    historical_high_discount = history['discount'].max()
    if historical_high_discount == 0:
        historical_high_discount_date = None
        first_discount = None
        first_discount_date = None
        last_discount = None
        last_discount_date = None
        discount_distribution = None
    else:
        historical_high_discount_date = history[history['discount'] == historical_high_discount]['timestamp'].iloc[0]
        first_discount = history[history['discount'] != 0]['discount'].iloc[0]
        first_discount_date = history[history['discount'] != 0]['timestamp'].iloc[0]
        last_discount = history[history['discount'] != 0]['discount'].iloc[-1]
        last_discount_date = history[history['discount'] != 0]['timestamp'].iloc[-1]
        discount_distribution = history[history['discount'] != 0].groupby(history['timestamp'].dt.month)['discount'].count()
    # print(discount_distribution.to_string())
    # calculate the average duration between discounts

    daily_price = daily_price_constuctor(history)

    average_duration_between_discounts_12months = None

    average_duration_of_discounts_12months = None

    avg_price = None

    avg_discount = None

    next_discount = None

    price_decay_rate = None



    price_items_inside = {
        'first_available_price': first_available_price,
        'regular_price_reduced': regular_price_reduced, 
        'price_reduced_date': price_reduced_date, 
        'first_available_date': first_available_date, 
        'last_available_date': last_available_date, 
        'historical_low': historical_low, 
        'historical_low_date': historical_low_date,
        'historical_high_discount': historical_high_discount,
        'historical_high_discount_date': historical_high_discount_date,
        'first_discount': first_discount,
        'first_discount_date': first_discount_date,
        'last_discount': last_discount,
        'last_discount_date': last_discount_date,
        'discount_distribution': discount_distribution,
        'average_duration_between_discounts_12months': average_duration_between_discounts_12months,
        'average_duration_of_discounts_12months': average_duration_of_discounts_12months,
        'avg_price': avg_price,
        'avg_discount': avg_discount,
        'next_discount': next_discount,
        'price_decay_rate': price_decay_rate

    }

    price_items_values = list(price_items_inside.values())
    # price_items_values = [i for i in range(len(price_items_inside.keys()))]

    # print(pd.Series(price_items_values, index=price_items_names))
    # print(history.to_string())
    # print(price_items_values)
    return price_items_values

# calculate_price_items(temp_)

# %%
# apply the function to the dataframe
df[price_items_names] = df.apply(calculate_price_items, axis=1, result_type='expand')
df.drop(columns=['price_history','assets'], inplace=True)
df.to_csv('price_items.csv')
# test_head = df.head(10)
# test_head[price_items_names] = test_head.apply(calculate_price_items, axis=1, result_type='expand')
# test_head.drop(columns=['price_history','assets','developers','reviews','stats','players'], inplace=True)
# print(test_head.to_string())
# Out:
# now processing: Dota 2
# now processing: Counter-Strike 2
# now processing: PUBG: BATTLEGROUNDS
# now processing: Palworld
# now processing: Team Fortress 2
# now processing: Apex Legends™
# now processing: New World
# now processing: Call of Duty®
# now processing: Grand Theft Auto V
# now processing: Left 4 Dead 2
# now processing: Rust
# now processing: Lost Ark
# now processing: Unturned
# now processing: Warframe
# now processing: HELLDIVERS 2
# now processing: War Thunder
# now processing: Elden Ring
# now processing: Terraria
# now processing: Brawlhalla
# now processing: Garry's Mod
# now processing: Baldur's Gate 3
# now processing: Tom Clancy's Rainbow Six® Siege
# now processing: Destiny 2
# now processing: Wallpaper Engine
# now processing: Half-Life 2: Lost Coast
# now processing: ARK: Survival Evolved
# now processing: Valheim
# now processing: Cyberpunk 2077
# now processing: PAYDAY 2
# now processing: Grand Theft Auto IV: Complete Edition
# now processing: The Forest
# now processing: Path of Exile
# now processing: Don't Starve Together
# now processing: NARAKA: BLADEPOINT
# now processing: Among Us
# now processing: Last Epoch
# now processing: Fall Guys
# now processing: Dead by Daylight
# now processing: The Witcher 3: Wild Hunt
# now processing: Warface: Clutch
# now processing: Paladins
# now processing: Stardew Valley
# now processing: Euro Truck Simulator 2
# now processing: Counter-Strike
# now processing: World of Warships
# now processing: Serena
# now processing: Phasmophobia
# now processing: Heroes & Generals
# now processing: Portal 2
# now processing: Rocket League
# now processing: Hogwarts Legacy
# now processing: Lethal Company
# now processing: Halo Infinite
# now processing: Counter-Strike: Source
# now processing: VRChat
# now processing: Battlefield™ 2042
# now processing: Half-Life
# now processing: Half-Life 2: Deathmatch
# now processing: Monster Hunter: World
# now processing: 鬼谷八荒 (Tale of Immortal)
# now processing: SMITE
# now processing: Raft
# now processing: Ring of Elysium
# now processing: Black Squad
# now processing: Red Dead Redemption 2
# now processing: Robocraft
# now processing: Dying Light
# now processing: Portal
# now processing: Human: Fall Flat
# now processing: Counter-Strike: Condition Zero Deleted Scenes
# now processing: Hollow Knight
# now processing: 7 Days to Die
# now processing: Z1 Battle Royale
# now processing: Street Warriors Online
# now processing: The Binding of Isaac: Rebirth
# now processing: Sekiro™: Shadows Die Twice - GOTY Edition
# now processing: Mount & Blade II: Bannerlord
# now processing: The Sims 4
# now processing: Trove
# now processing: Life is Strange 2
# now processing: EA SPORTS™ FIFA 23
# now processing: Fallout 4
# now processing: World of Tanks Blitz
# now processing: Battlefield™ V
# now processing: Cities: Skylines
# now processing: Arma 3
# now processing: Sid Meier's Civilization VI
# now processing: Ricochet
# now processing: PlanetSide 2
# now processing: Castle Crashers
# now processing: The Elder Scrolls V: Skyrim
# now processing: Project Zomboid
# now processing: DayZ
# now processing: NBA 2K20
# now processing: The Tiny Bang Story
# now processing: Sons Of The Forest
# now processing: Borderlands 2
# now processing: Dota Underlords
# now processing: No Man's Sky
# now processing: Minion Masters
# now processing: No More Room in Hell
# now processing: Counter-Strike: Condition Zero
# now processing: Tomb Raider
# now processing: Risk of Rain 2
# now processing: Geometry Dash
# now processing: Dark Souls III
# now processing: Day of Defeat: Source
# now processing: Deceit
# now processing: Hearts of Iron IV
# now processing: A Story About My Uncle
# now processing: The Elder Scrolls V: Skyrim Special Edition
# now processing: Guacamelee! Super Turbo Championship Edition
# now processing: Half-Life 2
# now processing: Hunt: Showdown
# now processing: Dirty Bomb
# now processing: Factorio
# now processing: SCP: Secret Laboratory
# now processing: Sea of Thieves: 2024 Edition
# now processing: Call of Duty: Black Ops III
# now processing: Halo: The Master Chief Collection
# now processing: Fallout Shelter
# now processing: Call of Duty: Modern Warfare 2 (2009)
# now processing: Grim Dawn
# now processing: Resident Evil 2
# now processing: MONSTER HUNTER RISE
# now processing: EA SPORTS FC™ 24
# now processing: Scrap Mechanic
# now processing: World of Tanks
# now processing: Fallout®: New Vegas™
# now processing: Black Desert
# now processing: Sid Meier's Civilization V
# now processing: Subnautica
# now processing: Chivalry: Medieval Warfare
# now processing: BeamNG.drive
# now processing: Team Fortress Classic
# now processing: Clicker Heroes
# now processing: Evolve Stage 2
# now processing: Europa Universalis IV
# now processing: Resident Evil 4 (2023)
# now processing: Day of Defeat
# now processing: Assetto Corsa
# now processing: Sven Co-op
# now processing: Vampire Survivors
# now processing: theHunter Classic
# now processing: Z1 Battle Royale: Test Server
# now processing: MultiVersus
# now processing: Tom Clancy's The Division™
# now processing: Life is Strange - Episode 1
# now processing: Hades
# now processing: Realm Royale Reforged
# now processing: Grand Theft Auto IV: The Complete Edition
# now processing: Blender
# now processing: Satisfactory
# now processing: Half-Life 2: Episode Two
# now processing: Age of Empires II (Retired)
# now processing: BattleBlock Theater
# now processing: It Takes Two
# now processing: Total War: WARHAMMER II
# now processing: Grand Theft Auto - San Andreas
# now processing: XCOM 2
# now processing: Half-Life Deathmatch: Source
# now processing: Call of Duty® 2
# now processing: Star Wars: The Old Republic
# now processing: Assassin's Creed IV Black Flag
# now processing: Neverwinter
# now processing: Slay the Spire
# now processing: BioShock Infinite
# now processing: Left 4 Dead
# now processing: Devil May Cry 5
# now processing: Mordhau
# now processing: Forza Horizon 4
# now processing: DOOM
# now processing: Content Warning
# now processing: RaceRoom Racing Experience
# now processing: Splitgate
# now processing: Dead Cells
# now processing: Divinity: Original Sin 2 - Definitive Edition
# now processing: Cry of Fear
# now processing: Football Manager 2020
# now processing: Hitman 2
# now processing: Infestation: The New Z
# now processing: Counter-Strike Nexon: Studio
# now processing: Business Tour - Board Game with Online Multiplayer
# now processing: Doki Doki Literature Club
# now processing: Total War: THREE KINGDOMS
# now processing: Cuphead
# now processing: People Playground
# now processing: God of War
# now processing: The Cycle: Frontier
# now processing: Eternal Return
# now processing: Doom Eternal
# now processing: POSTAL 2
# now processing: POSTAL
# now processing: Titanfall 2
# now processing: SCUM
# now processing: Stray
# now processing: Middle-earth: Shadow of Mordor
# now processing: theHunter™: Call of the Wild
# now processing: Loadout
# now processing: Little Nightmares
# now processing: Undertale
# now processing: ULTRAKILL
# now processing: Dying Light 2 Stay Human - Reloaded Edition
# now processing: APB Reloaded
# now processing: RimWorld
# now processing: Mount & Blade: Warband
# now processing: Conan Exiles
# now processing: Freestyle 2: Street Basketball
# now processing: Braveland
# now processing: STAR WARS™ Battlefront II (Classic, 2005)
# now processing: Russian Fishing 4
# now processing: Saints Row IV: Re-Elected
# now processing: Forza Horizon 5
# now processing: For Honor
# now processing: Deep Rock Galactic
# now processing: FINAL FANTASY XIV Online
# now processing: The Descendant
# now processing: Just Cause 3
# now processing: Divide by Sheep
# now processing: Saints Row: The Third
# now processing: Fishing Planet
# now processing: Battlefield 1
# now processing: Starbound
# now processing: DCS World Steam Edition
# now processing: Just Cause 2
# now processing: Outlast
# now processing: Northgard
# now processing: Rise of the Tomb Raider
# now processing: Plants vs. Zombies GOTY Edition
# now processing: Starfield
# now processing: Realm of the Mad God Exalt
# now processing: Darkest Dungeon
# now processing: Magicka
# now processing: Killing Floor
# now processing: Bloons TD 6
# now processing: AdVenture Capitalist
# now processing: Alien Swarm
# now processing: INSURGENCY
# now processing: Amnesia: The Dark Descent
# now processing: The Elder Scrolls Online
# now processing: Totally Accurate Battle Simulator
# now processing: DAVE THE DIVER
# now processing: Call of Duty: Modern Warfare 3 (2011)
# now processing: Getting Over It with Bennett Foddy
# now processing: NBA 2K21
# now processing: Survarium
# now processing: Borderlands 3
# now processing: Tabletop Simulator
# now processing: Battlerite
# now processing: The Witcher 2: Assassins of Kings Enhanced Edition
# now processing: Warhammer 40,000: Space Marine - Anniversary Edition
# now processing: FTL: Faster Than Light
# now processing: Company of Heroes 2
# now processing: Dead Frontier 2
# now processing: Space Engineers
# now processing: Stumble Guys
# now processing: Albion Online
# now processing: DISTRAINT: Deluxe Edition
# now processing: Half-Life: Blue Shift
# now processing: Stellaris
# now processing: Celeste
# now processing: Dyson Sphere Program
# now processing: Far Cry 3
# now processing: ArmA 2 Operation Arrowhead
# now processing: PAYDAY The Heist
# now processing: Ultimate Custom Night
# now processing: Call of Duty®: Black Ops II
# now processing: KurtzPel
# now processing: FIFA 22
# now processing: Poppy Playtime
# now processing: BattleBit Remastered
# now processing: Age of Empires II: Definitive Edition
# now processing: Sniper Elite V2
# now processing: Ready Or Not
# now processing: Need for Speed™ Heat
# now processing: Crossout
# now processing: Beat Saber
# now processing: Enter the Gungeon
# now processing: INSIDE
# now processing: Stick Fight: The Game
# now processing: Mad Max
# now processing: The Lord of the Rings Online™
# now processing: V Rising
# now processing: Fallout 76
# now processing: Marvel's Spider-Man Remastered
# now processing: Yu-Gi-Oh! Duel Links
# now processing: Wolfenstein: Youngblood
# now processing: BioShock™
# now processing: Grounded
# now processing: Oxygen Not Included
# now processing: Half-Life: Alyx
# now processing: Resident Evil Village
# now processing: Frostpunk
# now processing: Hades II
# now processing: Batman: Arkham Knight
# now processing: Middle-earth: Shadow of War
# now processing: Borderlands: The Pre-Sequel
# now processing: CRSED: Cuisine Royale
# now processing: Stay Out
# now processing: Total War SHOGUN™ 2
# now processing: BLOCKADE 3D
# now processing: Mirror 2: Project X
# now processing: Far Cry 5
# now processing: Granblue Fantasy: Relink
# now processing: American Truck Simulator
# now processing: Crusader Kings II
# now processing: Last Man Standing
# now processing: Prison Architect
# now processing: The Expendabros
# now processing: House Flipper
# now processing: Hitman
# now processing: The Witcher: Enhanced Edition Director's Cut
# now processing: Call of Duty: World at War
# now processing: Half-Life: Opposing Force
# now processing: Kerbal Space Program
# now processing: Call of Duty®: Modern Warfare® 3
# now processing: Fistful of Frags
# now processing: Saints Row 2
# now processing: Sniper Elite 4
# now processing: Total War: ROME II - Emperor Edition
# now processing: Skullgirls 2nd Encore
# now processing: Elite Dangerous
# now processing: BROFORCE
# now processing: Rising Storm 2: Vietnam
# now processing: Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# now processing: The Isle
# now processing: Party Animals
# now processing: Hotline Miami
# now processing: Spiral Knights
# now processing: Days Gone
# now processing: XCOM: Enemy Unknown
# now processing: Half-Life 2: Episode One
# now processing: Transformice
# now processing: Century: Age of Ashes
# now processing: Trine 2: Complete Story
# now processing: The Walking Dead
# now processing: Killing Floor 2
# now processing: Ori and the Will of the Wisps
# now processing: Kathy Rain
# now processing: Don't Starve
# now processing: BioShock Remastered
# now processing: Block N Load
# now processing: Mafia II (Classic)
# now processing: Call of Duty: Black Ops II - Multiplayer
# now processing: Overcooked! 2
# now processing: Defiance
# now processing: PAYDAY 3
# now processing: Assassin's Creed Origins
# now processing: Mirror's Edge
# now processing: Helltaker
# now processing: Mortal Kombat X
# now processing: Shadow Warrior
# now processing: Company of Heroes - Legacy Edition
# now processing: Codename CURE
# now processing: Pummel Party
# now processing: Crypt of the Necrodancer
# now processing: My Summer Car
# now processing: Dragon Ball FighterZ
# now processing: Black Mesa
# now processing: MORTAL KOMBAT 11
# now processing: Dishonored 2
# now processing: Resident Evil 7 Biohazard
# now processing: Gang Beasts
# now processing: ASTRONEER
# now processing: The Binding of Isaac
# now processing: Warhammer: Vermintide 2
# now processing: Blacklight: Retribution
# now processing: Assassin's Creed 2
# now processing: Ultimate Chicken Horse
# now processing: Cookie Clicker
# now processing: World of Guns: Gun Disassembly
# now processing: Layers of Fear (2016)
# now processing: Tom Clancy's Ghost Recon:Wildlands
# now processing: Hitman Absolution
# now processing: Watch_Dogs® 2 - Ubisoft Pack
# now processing: South Park: The Stick of Truth
# now processing: Hotline Miami 2: Wrong Number
# now processing: DARK SOULS™ II: Scholar of the First Sin
# now processing: Grand Theft Auto III
# now processing: This War of Mine
# now processing: 太吾绘卷 The Scroll Of Taiwu
# now processing: Kingdom Come: Deliverance
# now processing: Conqueror's Blade
# now processing: ARK: The Survival Of The Fittest
# now processing: METAL GEAR SOLID V: THE PHANTOM PAIN
# now processing: Sins of a Solar Empire: Rebellion
# now processing: No Rest For The Wicked!
# now processing: Remnant: From the Ashes
# now processing: Escape the Backrooms
# now processing: Friday the 13th: The Game
# now processing: Goat Simulator
# now processing: Detroit: Become Human
# now processing: Hero Siege
# now processing: Tree of Savior (English Ver.)
# now processing: Warhammer 40,000: Darktide
# now processing: Crusader Kings III
# now processing: Assassin's Creed Odyssey
# now processing: Dungeon Defenders
# now processing: Titan Quest Anniversary Edition
# now processing: Phantasy Star Online 2 New Genesis
# now processing: Alien: Isolation
# now processing: Ori and the Blind Forest: Definitive Edition
# now processing: Heart of a Warrior
# now processing: The Day Before
# now processing: Everlasting Summer
# now processing: Quake Live
# now processing: Papers, Please
# now processing: The Awesome Adventures of Captain Spirit
# now processing: Metro 2033 Redux
# now processing: Dragons Dogma - Dark Arisen
# now processing: Hell Let Loose
# now processing: Insurgency: Sandstorm
# now processing: Planet Zoo
# now processing: Metro Exodus
# now processing: METAL GEAR RISING: REVENGEANCE
# now processing: 嗜血印 Bloody Spell
# now processing: GunZ 2: The Second Duel
# now processing: Plague Inc: Evolved
# now processing: Metin2
# now processing: Pacify
# now processing: Magic Duels
# now processing: DC Universe Online
# now processing: TrackMania Nations Forever
# now processing: Metro Last Light Redux
# now processing: Kenshi
# now processing: TEKKEN 7
# now processing: Jurassic World Evolution
# now processing: BioShock 2
# now processing: S.K.I.L.L. - Special Force 2 (Shooter)
# now processing: The I of the Dragon
# now processing: Toribash
# now processing: America's Army: Proving Grounds
# now processing: The Crew 2
# now processing: SpeedRunners
# now processing: Resident Evil 6
# now processing: Argo
# now processing: The Stanley Parable
# now processing: Need for Speed™ Hot Pursuit
# now processing: Orcs Must Die! 2
# now processing: Homefront
# now processing: Who's Your Daddy
# now processing: The Escapists 2
# now processing: Sniper Elite 3
# now processing: Battlefield: Bad Company™ 2
# now processing: Lost Castle「失落城堡」
# now processing: Just Survive
# now processing: Football Manager 2022
# now processing: Batman: Arkham Origins
# now processing: Mirror
# now processing: Total War: WARHAMMER III
# now processing: Fallout: A Post Nuclear Role Playing Game
# now processing: The Long Dark
# now processing: Wolcen: Lords of Mayhem
# now processing: WARMODE
# now processing: F1 2015
# now processing: Capcom Arcade Stadium
# now processing: Bully: Scholarship Edition
# now processing: SPORE
# now processing: NBA 2K19
# now processing: Inscryption
# now processing: Golf With Your Friends
# now processing: Dark Souls™: Prepare to Die™ Edition
# now processing: Football Manager 2021
# now processing: Call of Duty®: Black Ops
# now processing: Bless Unleashed
# now processing: Wolfenstein®: The New Order
# now processing: NieR: Automata
# now processing: LIMBO
# now processing: Dome Keeper
# now processing: STAR WARS Jedi: Fallen Order™
# now processing: Grand Theft Auto: Episodes from Liberty City
# now processing: Enclave
# now processing: Farming Simulator 19
# now processing: Batman Arkham City Game of the Year Edition
# now processing: Age of Empires IV: Anniversary Edition
# now processing: Ori and the Blind Forest
# now processing: Noita
# now processing: Soul Dossier
# now processing: Alan Wake
# now processing: Gunfire Reborn
# now processing: Manor Lords
# now processing: Enshrouded
# now processing: Street Fighter V
# now processing: Governor of poker 3
# now processing: They Are Billions
# now processing: Total War: Attila
# now processing: Half-Life: Source
# now processing: RISK® Global Domination
# now processing: DiRT Rally
# now processing: Grand Theft Auto - Vice City
# now processing: Microsoft Flight Simulator 40th Anniversary Edition
# now processing: Alice: Madness Returns
# now processing: Subnautica: Below Zero
# now processing: EVE Online
# now processing: Hellblade: Senua's Sacrifice
# now processing: Just Cause 2: Multiplayer Mod
# now processing: Banished
# now processing: Dishonored
# now processing: Trine Enchanted Edition
# now processing: Dungeon Defenders II
# now processing: Dead Bits
# now processing: Spec Ops: The Line
# now processing: Sanctum 2
# now processing: Ironsight
# now processing: DEVOUR
# now processing: Darksiders II Deathinitive Edition
# now processing: Super Meat Boy
# now processing: Sleeping Dogs
# now processing: ARMORED CORE VI FIRES OF RUBICON
# now processing: Muse Dash
# now processing: Tales of Arise
# now processing: Brütal Legend
# now processing: Serious Sam 3: BFE
# now processing: Five Nights at Freddy's
# now processing: Uno
# now processing: Resident Evil 4 (2005)
# now processing: Star Trek Online
# now processing: Age of Empires® III (2007)
# now processing: Dragon's Dogma 2
# now processing: Aura Kingdom
# now processing: Mitos.is: The Game
# now processing: Farming Simulator 22
# now processing: L.A. Noire
# now processing: Gotham City Impostors: Free To Play
# now processing: Awesomenauts - the 2D moba
# now processing: Warhammer® 40,000: Dawn of War® II
# now processing: Fallout 3: Game of the Year Edition
# now processing: Call Of Duty 4: Modern Warfare (2007)
# now processing: Jotun: Valhalla Edition
# now processing: Kholat
# now processing: Surviving Mars
# now processing: The Red Solstice
# now processing: Men of War: Assault Squad 2 
# now processing: MapleStory
# now processing: Dark Souls Remastered
# now processing: Planet Coaster
# now processing: Source Filmmaker
# now processing: Teardown
# now processing: War Robots
# now processing: SOMA
# now processing: Krunker
# now processing: For The King
# now processing: The Sims 3
# now processing: Darksiders
# now processing: Batman: Arkham Asylum Game of the Year Edition
# now processing: Deus Ex: Human Revolution™  Director's Cut
# now processing: Totally Accurate Battlegrounds
# now processing: Call of Juarez: Gunslinger
# now processing: Dead Space 2
# now processing: Pathfinder: Kingmaker - Enhanced Plus Edition
# now processing: RIFT™
# now processing: Quake Champions
# now processing: HELLDIVERS™ Dive Harder Edition
# now processing: Slime Rancher
# now processing: Max Payne 3
# now processing: Age of Mythology: Extended Edition
# now processing: The Bureau: XCOM Declassified
# now processing: Deus Ex: Mankind Divided
# now processing: RESIDENT EVIL 3
# now processing: Torchlight II
# now processing: Psychonauts
# now processing: Cult of the Lamb
# now processing: Spellbreak
# now processing: Football Manager™ 2017
# now processing: Car Mechanic Simulator 2018
# now processing: Brotato
# now processing: Outlast 2
# now processing: Children of Morta
# now processing: Green Hell
# now processing: The Elder Scrolls IV: Oblivion Game of the Year Edition Deluxe
# now processing: Sniper Elite 5
# now processing: Mafia: Definitive Edition
# now processing: Sleeping Dogs™ Definitive Edition
# now processing: Firewatch
# now processing: DRAGON BALL XENOVERSE 2
# now processing: Marvel's Midnight Suns
# now processing: Double Action: Boogaloo
# now processing: Kingdom: Classic
# now processing: The Outlast Trials
# now processing: Moonlighter
# now processing: Freddy Fazbear's Pizzeria Simulator
# now processing: Disco Elysium - The Final Cut
# now processing: SoulWorker - Anime Action MMO
# now processing: Line of Sight
# now processing: Microsoft Flight Simulator X: Steam Edition
# now processing: Guild Wars 2
# now processing: Katana ZERO
# now processing: Orcs Must Die! 3
# now processing: Mafia
# now processing: QUAKE
# now processing: Monster Hunter Stories 2: Wings of Ruin
# now processing: Duck Game
# now processing: S.T.A.L.K.E.R. Call of Pripyat
# now processing: Life is Strange: Before the Storm
# now processing: Shadowrun Returns
# now processing: Street Fighter 6
# now processing: Dead Space (2008)
# now processing: Iron Snout
# now processing: ORION: Prelude
# now processing: Nioh: Complete Edition
# now processing: Prey
# now processing: MechWarrior Online™ Legends
# now processing: Squad
# now processing: Supermarket Simulator
# /var/folders/7m/bpynmdb95w587ztb6nlzcgg80000gn/T/ipykernel_16409/684933141.py:23: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   history['timestamp'] = pd.to_datetime(history['timestamp'],utc=True)
# now processing: Neon Abyss
# now processing: Football Manager 2023
# now processing: Creative Destruction
# now processing: Chivalry 2
# now processing: Soundpad
# now processing: Kingdom: Two Crowns
# now processing: Serious Sam 2
# now processing: Knight Online
# now processing: Naruto Shippuden: Ultimate Ninja Storm 4
# now processing: Resident Evil Revelations 2 / Biohazard Revelations 2 Deluxe Edition
# now processing: Warhammer 40,000: Rogue Trader
# now processing: A Way Out
# now processing: Ghost of Tsushima DIRECTOR'S CUT
# now processing: Resident Evil® 5
# now processing: Lords Of The Fallen
# now processing: Naruto to Boruto Shinobi Striker
# now processing: BioShock 2 Remastered
# now processing: Shadowverse CCG
# now processing: OUTRIDERS
# now processing: Ghostrunner
# now processing: Alien Swarm: Reactive Drop
# now processing: Tropico 4
# now processing: State of Decay 2: Juggernaut Edition
# now processing: Vindictus
# now processing: Back to Bed
# now processing: RuneScape
# now processing: KARDS - The WW2 Card Game
# now processing: Football Manager 2019
# now processing: Besiege
# now processing: Endless Space: Definitive Edition
# now processing: To the Moon
# now processing: Assassin's Creed Syndicate
# now processing: Ace Combat 7: Skies Unknown
# now processing: Magicka 2
# now processing: Tribes of Midgard
# now processing: Hacknet
# now processing: Star Wars: Knights of the Old Republic
# now processing: Romero's Aftermath
# now processing: Total War: Empire - Definitive Edition
# now processing: Operation: Harsh Doorstop
# now processing: AirMech
# now processing: The Evil Within
# now processing: The Elder Scrolls IV: Oblivion® Game of the Year Edition
# now processing: Borderlands: Game of the Year
# now processing: Pathfinder: Wrath of the Righteous - Enhanced Edition
# now processing: AX:EL - Air XenoDawn
# now processing: Shadow Of The Tomb Raider - Definitive Edition
# now processing: A Dance of Fire and Ice
# now processing: Pavlov
# now processing: Darksiders III
# now processing: South Park™: The Fractured but Whole™
# now processing: Endless Legend
# now processing: Need for Speed Payback
# now processing: Far Cry
# now processing: Red Dead Online
# now processing: Depth
# now processing: Horizon Zero Dawn™ Complete Edition
# now processing: Sabre Team
# now processing: OpenTTD
# now processing: Dark Deception
# now processing: Cities: Skylines II
# now processing: Stories: The Path of Destinies
# now processing: Riders of Icarus
# now processing: Fallen Earth Classic
# now processing: Hitman Blood Money
# now processing: Star Wars Battlefront® II
# now processing: Pillars of Eternity
# now processing: Mafia II: Definitive Edition
# now processing: Ryse: Son of Rome
# now processing: Gene Shift Auto
# now processing: Assassin's Creed® Rogue
# now processing: Wolfenstein II: The New Colossus
# now processing: Gigantic
# now processing: BLOCKPOST LEGACY
# now processing: Game Dev Tycoon
# now processing: Burnout™ Paradise: The Ultimate Box
# now processing: Baldur's Gate: Enhanced Edition
# now processing: Idle Champions of the Forgotten Realms
# now processing: Total War™: WARHAMMER®
# now processing: War Trigger 3
# now processing: Wreckfest
# now processing: Kingdoms and Castles
# now processing: Call of Duty: WWII
# now processing: THIEF
# now processing: Emily is Away
# now processing: Minimalism
# now processing: Yakuza 0
# now processing: Crysis Warhead
# now processing: DOOM (1993)
# now processing: Risk of Rain (2013)
# now processing: PC Building Simulator
# now processing: GTFO
# now processing: Gear Up
# now processing: Mass Effect 2 (2010 Edition)
# now processing: CarX Drift Racing Online
# now processing: Orcs Must Die!
# now processing: Road 96
# now processing: Ace of Spades: Battle Builder
# now processing: Company of Heroes: Opposing Fronts
# now processing: Dragon Age: Origins - Ultimate Edition
# now processing: Creativerse
# now processing: PICO PARK
# now processing: Command & Conquer™ Remastered Collection
# now processing: Murderous Pursuits
# now processing: The Darkness II
# now processing: Day of Infamy
# now processing: GRIS
# now processing: Barotrauma
# now processing: Verdun
# now processing: Back 4 Blood
# now processing: Ravenfield
# now processing: Tropico 6
# now processing: Resident Evil / biohazard HD REMASTER
# now processing: The Elder Scrolls III: Morrowind® Game of the Year Edition
# now processing: Star Wars Republic Commando™
# now processing: Far Cry® 4
# now processing: Rise of Nations: Extended Edition
# now processing: We Were Here
# now processing: Endless Space 2
# now processing: SUPERHOT
# now processing: SoulWorker
# now processing: Rain World
# now processing: HITMAN World of Assassination
# now processing: X4: Foundations
# now processing: Shakes and Fidget
# now processing: EA SPORTS™ FIFA 21
# now processing: GWENT: THE WITCHER CARD GAME
# now processing: The Elder Scrolls: Legends
# now processing: Superliminal
# now processing: Return to Castle Wolfenstein
# now processing: Total War: Napoleon - Definitive Edition
# now processing: Bayonetta
# now processing: STAR WARS™ Battlefront (Classic, 2004)
# now processing: Supreme Commander 2
# now processing: Mark of the Ninja
# now processing: Natural Selection 2
# now processing: Gray Zone Warfare
# now processing: BATTLETECH
# now processing: Stronghold Crusader 2
# now processing: Tricky Towers
# now processing: Shadow Warrior 2
# now processing: Sid Meier's Civilization: Beyond Earth
# now processing: ROUNDS
# now processing: Surgeon Simulator
# now processing: Assassin's Creed Brotherhood
# now processing: Brothers - A Tale of Two Sons
# now processing: Crosshair X
# now processing: Chained Together
# now processing: Aliens: Fireteam Elite
# now processing: Tom Clancy's Splinter Cell Blacklist
# now processing: Assassin's Creed™ Director's Cut Edition
# now processing: Blade & Sorcery
# now processing: Medal of Honor
# now processing: Warhammer 40,000 Dawn of War III
# now processing: Dark Messiah of Might & Magic
# now processing: Tiny Tina's Wonderlands
# now processing: Transistor
# now processing: Aeon Command
# now processing: ATLAS
# now processing: Elsword
# now processing: Torchlight
# now processing: Warhammer® 40,000®: Dawn of War® II - Chaos Rising
# now processing: Warhammer 40,000: Inquisitor - Martyr
# now processing: Project Winter
# now processing: Data Hacker - Initiation
# now processing: Wargame: Red Dragon
# now processing: Scribblenauts Unlimited
# now processing: ArcheBlade™
# now processing: Viscera Cleanup Detail: Santa's Rampage
# now processing: Gorilla Tag
# now processing: Keep Talking and Nobody Explodes
# now processing: Remnant II
# now processing: Crush Crush
# now processing: Glass Masquerade
# now processing: The Riftbreaker
# now processing: Wakfu
# now processing: Train Simulator Classic 2024
# now processing: Total War: Medieval II - Definitive Edition
# now processing: Rec Room
# now processing: Just Cause
# now processing: School of Dragons
# now processing: Mass Effect (2007)
# now processing: Arma: Cold War Assault
# now processing: Balatro
# now processing: FEZ
# now processing: Digimon Masters Online
# now processing: Ghostwire Tokyo
# now processing: The Ascent
# now processing: Unheard - Voices of Crime
# now processing: Ring of Fire Prologue
# now processing: The Surge
# now processing: Evolvation
# now processing: SOULCALIBUR VI
# now processing: DRAGON BALL XENOVERSE
# now processing: Far Cry 2
# now processing: Gothic 3
# now processing: Two Point Hospital
# now processing: Battlefield 3
# now processing: Warhammer: End Times - Vermintide
# now processing: Lobotomy Corporation | Monster Management Simulation
# now processing: Aliens vs. Predator
# now processing: Divinity: Original Sin Enhanced Edition
# now processing: Town of Salem
# now processing: Control Ultimate Edition
# now processing: DRAGON BALL Z: KAKAROT
# now processing: Orcs Must Die! Unchained
# now processing: Quantum Break
# now processing: Running with Rifles
# now processing: Pizza Tower
# now processing: Battlefield 4
# now processing: Lord of the Rings: War in the North
# now processing: Sid Meier's Civilization® III: Complete
# now processing: S.T.A.L.K.E.R. Shadow of Chernobyl
# now processing: Kingdoms of Amalur: Reckoning™
# now processing: BrainBread 2
# now processing: Warhammer 40,000: Dawn of War II - Retribution
# now processing: ONE PIECE: PIRATE WARRIORS 4
# now processing: Dragons and Titans
# now processing: Deponia - The Complete Journey
# now processing: A Plague Tale: Innocence
# now processing: Old School RuneScape
# now processing: Saving Grace
# now processing: Artifact
# now processing: Modern Combat Versus
# now processing: Shadow Tactics: Blades of the Shogun
# now processing: Watch_Dogs
# now processing: Bloodstained: Ritual of the Night
# now processing: Dredge
# now processing: Catan Universe
# now processing: Bright Memory: Infinite
# now processing: Panzar
# now processing: Hand Simulator
# now processing: Sherlock Holmes: The Devil's Daughter
# now processing: PowerWash Simulator
# now processing: Draw & Guess
# now processing: Company of Heroes
# now processing: Metal Gear Solid V: Ground Zeroes
# now processing: FINAL FANTASY VII
# now processing: Star Wars: The Force Unleashed: Ultimate Sith Edition
# now processing: The Henry Stickmin Collection
# now processing: GUILTY GEAR -STRIVE
# now processing: Star Wars® Empire at War™: Gold Pack
# now processing: DMC - Devil May Cry
# now processing: The Escapists
# now processing: Bendy and the Ink Machine
# now processing: Cortex Command
# now processing: Star Wars: Jedi Knight: Jedi Academy
# now processing: Oddworld: Abe's Oddysee
# now processing: Metal: Hellsinger
# now processing: Shop Titans
# now processing: Call of Duty: Infinite Warfare
# now processing: Thief Simulator
# now processing: The Evil Within 2
# now processing: Age of Empires III: Definitive Edition
# now processing: Loop Hero
# now processing: World War 3
# now processing: Heroes of Might & Magic III - HD Edition
# now processing: Turbo Pug
# now processing: CS2D
# now processing: Tropico 5
# now processing: BIGFOOT
# now processing: Persona 5 Royal
# now processing: Crysis
# now processing: Eador. Masters of the Broken World
# now processing: SIGNALIS
# now processing: Killer is Dead - Nightmare Edition
# now processing: Rome: Total War Collection
# now processing: Hitman 2 - Silent Assassin
# now processing: Blasphemous
# now processing: Squad 44
# now processing: MudRunner
# now processing: Call to Arms
# now processing: Bloons TD Battles
# now processing: OMORI
# now processing: Wizard of Legend
# now processing: 音灵 INVAXION
# now processing: Mass Effect™: Andromeda Deluxe Edition
# now processing: Graveyard Keeper
# now processing: Sniper Ghost Warrior 2
# now processing: Capcom Arcade 2nd Stadium
# now processing: Bright Memory
# now processing: Knights & Merchants
# now processing: Call of Duty®: Ghosts
# now processing: Crysis 2: Maximum Edition
# now processing: Zombie Army Trilogy
# now processing: Injustice: Gods Among Us - Ultimate Edition
# now processing: Red Faction: Armageddon
# now processing: Serious Sam HD: The First Encounter
# now processing: Deus Ex: Game of the Year Edition
# now processing: Mortal Kombat Komplete Edition
# now processing: Warriors of Vilvatikta
# now processing: Outer Wilds
# now processing: Ragnarok Online 2
# now processing: Warhammer 40,000: Chaos Gate - Daemonhunters
# now processing: Baldur's Gate II: Enhanced Edition
# now processing: How To Survive
# now processing: EARTH DEFENSE FORCE 4.1 The Shadow of New Despair
# now processing: Spelunky
# now processing: Guns of Icarus Online
# now processing: Assetto Corsa Competizione
# now processing: Farming Simulator 17
# now processing: Move or Die
# now processing: Braid
# now processing: Far Cry® New Dawn
# now processing: DiRT Rally 2.0
# now processing: Amnesia: A Machine For Pigs
# now processing: The Talos Principle
# now processing: Darksiders Warmastered Edition
# now processing: Victoria 3
# now processing: STEEP
# now processing: Polygon
# now processing: Heaven Forest Nights
# now processing: BRINK
# now processing: Unrailed!
# now processing: Persona 4 Golden
# now processing: IdleOn - The Idle RPG
# now processing: AMID EVIL
# now processing: Age of History II
# now processing: Farm Together
# now processing: 3DMark
# now processing: FINAL FANTASY XV WINDOWS EDITION
# now processing: DYNASTY WARRIORS 8: Xtreme Legends Complete Edition
# now processing: Super Animal Royale
# now processing: Beholder
# now processing: Paint the Town Red
# now processing: X-Com: UFO Defense
# now processing: Sands of Salzaar
# now processing: SimCity 4 Deluxe Edition
# now processing: Universe Sandbox
# now processing: Predecessor
# now processing: Command & Conquer Red Alert 3
# now processing: Viscera Cleanup Detail
# now processing: Deadlink
# now processing: Dino D-Day
# now processing: Woodle Tree Adventures
# now processing: Modern Combat 5
# now processing: GUNS and ROBOTS
# now processing: Untitled Goose Game
# now processing: The Lab
# now processing: Portal Knights
# now processing: DIVINITY: ORIGINAL SIN CLASSIC
# now processing: Fallout Tactics: Brotherhood of Steel
# now processing: Five Nights at Freddy's: Security Breach
# now processing: Sakura Clicker
# now processing: Sonic Generations Collection
# now processing: Bacteria
# now processing: Hitman: Codename 47
# now processing: Code Vein
# now processing: Inside The Backrooms
# now processing: Styx: Master of Shadows
# now processing: Bastion
# now processing: The Walking Dead: Season Two
# now processing: TERA - Action MMORPG
# now processing: Brick Rigs
# now processing: GOD EATER 3
# now processing: Transport Fever
# now processing: Project CARS
# now processing: Orwell: Keeping an Eye On You
# now processing: Not For Broadcast
# now processing: LEGO Marvel Super Heroes
# now processing: High Octane Drift
# now processing: Overlord II
# now processing: Strife
# now processing: BONEWORKS
# now processing: Dead Rising 3 Apocalypse Edition
# now processing: The Ship: Murder Party
# now processing: Stronghold HD (2012)
# now processing: Alan Wake's American Nightmare
# now processing: Streets of Rogue
# now processing: Stronghold Crusader HD
# now processing: Stranded Deep
# now processing: Cruelty Squad
# now processing: Bless Online
# now processing: Spooky's Jump Scare Mansion
# now processing: Radical Heights
# now processing: Sam & Max 104: Abe Lincoln Must Die!
# now processing: Sid Meier's Civilization IV
# now processing: LEGO® Star Wars™: The Skywalker Saga
# now processing: The LEGO® NINJAGO® Movie Video Game
# now processing: F.E.A.R. 3
# now processing: Poker Night at the Inventory
# now processing: Medieval Dynasty
# now processing: Heaven Forest VR MMO
# now processing: Action Taimanin
# now processing: Hot Dogs, Horseshoes & Hand Grenades
# now processing: Space Pilgrim Episode I: Alpha Centauri
# now processing: Infestation: Survivor Stories 2020
# now processing: Pillars of Eternity II: Deadfire
# now processing: Monaco: What's Yours Is Mine
# now processing: Zero Escape: Zero Time Dilemma
# now processing: ArcheAge
# now processing: Fortified
# now processing: Secret in Story
# now processing: Crucible Beta
# now processing: F.E.A.R.: Perseus Mandate
# now processing: F.E.A.R.: EXTRACTION POINT
# now processing: Prismata
# now processing: AudioSurf
# now processing: Aseprite
# now processing: Warhammer® 40,000: Dawn of War® - Soulstorm
# now processing: Worms Armageddon
# now processing: Worms Revolution
# now processing: SpongeBob SquarePants: Battle for Bikini Bottom - Rehydrated
# now processing: Thunder Tier One
# now processing: eFootball PES 2021 SEASON UPDATE
# now processing: S.T.A.L.K.E.R. Clear Sky
# now processing: Escape Room - Der kranke Kollege
# now processing: BRAIN / OUT
# now processing: Her Story
# now processing: NBA 2K23
# now processing: Warhammer® 40,000: Dawn of War® - Dark Crusade
# now processing: Supraland
# now processing: Craftopia
# now processing: Tricolour Lovestory
# now processing: Mafia III: Definitive Edition
# now processing: Far Cry 3: Blood Dragon
# now processing: Wobbly Life
# now processing: 暖雪 Warm Snow
# now processing: Atomic Heart
# now processing: Cell to Singularity - Evolution Never Ends
# now processing: Fallout 2: A Post Nuclear Role Playing Game
# now processing: Demonologist
# now processing: Project CARS 2
# now processing: Turmoil
# now processing: Supreme Commander Forged Alliance
# now processing: Furi
# now processing: The Witness
# now processing: STAR WARS™ Knights of the Old Republic™ II - The Sith Lords™
# now processing: Car Mechanic Simulator 2021
# now processing: The Culling
# now processing: Relic Hunters Zero: Remix
# now processing: Builders of Egypt: Prologue
# now processing: Moonbase Alpha
# now processing: The Wolf Among Us
# now processing: Sonic Mania
# now processing: Strobophagia | Rave Horror
# now processing: SEGA Mega Drive and Genesis Classics
# now processing: Poly Bridge
# now processing: Dungeon of the Endless
# now processing: Darkwood
# now processing: Unreal Tournament 3
# now processing: Serious Sam 4
# now processing: Drunken Wrestlers 2
# now processing: Rage
# now processing: Cossacks 3
# now processing: SteamVR
# now processing: Knockout City™
# now processing: Rivals of Aether
# now processing: Portal 2 Sixense Perceptual Pack
# now processing: My Friend Pedro
# now processing: Gauntlet™ Slayer Edition
# now processing: Crysis 2 Remastered
# now processing: ARK: Survival Ascended
# now processing: Outward Definitive Edition
# now processing: Mass Effect™ Legendary Edition
# now processing: Dishonored: Death of the Outsider
# now processing: 3on3 FreeStyle: Rebound
# now processing: Night In The Woods
# now processing: LEGO: The Lord of the Rings
# now processing: Torque Drift
# now processing: MOBIUS FINAL FANTASY
# now processing: Duke Nukem Forever
# now processing: QUAKE II
# now processing: Buckshot Roulette
# now processing: LET IT DIE
# now processing: Need for Speed™ Rivals
# now processing: Invisible, Inc.
# now processing: Sunless Sea
# now processing: eFootball PES 2020
# now processing: Spyro™ Reignited Trilogy
# now processing: The Pillage
# now processing: Assassin's Creed Revelations
# now processing: Armello
# now processing: Stormworks: Build and Rescue
# now processing: Jump Force
# now processing: Scribble It!
# now processing: Punch Club
# now processing: Tales of Berseria
# now processing: Champions Online
# now processing: SNOW - The Ultimate Edition
# now processing: Minecraft Dungeons
# now processing: Victoria II
# now processing: World of Goo
# now processing: Kingdoms of Amalur: Re-Reckoning
# now processing: Resident Evil 3: Raccoon City Demo
# now processing: Foxhole
# now processing: VEGA Conflict
# now processing: Stoneshard
# now processing: Fable Anniversary
# now processing: PlateUp!
# now processing: Spiritfarer: Farewell Edition
# now processing: Zula Global
# now processing: Ground Branch
# now processing: Cthulhu Saves the World
# now processing: F.E.A.R.
# now processing: Assassin's Creed® Unity
# now processing: Deus Ex Invisible War
# now processing: World War Z
# now processing: Townscaper
# now processing: War Selection
# now processing: The Long Drive
# now processing: Euro Truck Simulator
# now processing: 100% Orange Juice
# now processing: Blood Bowl 2
# now processing: Prime World
# now processing: ShareX
# now processing: Red Faction Guerrilla Steam Edition
# now processing: Prototype® 2
# now processing: Trine 4: The Nightmare Prince
# now processing: The Elder Scrolls V: Skyrim VR
# now processing: Marauders
# now processing: ICEY
# now processing: Freebie
# now processing: Tyranny
# now processing: Devil May Cry® 4 Special Edition
# now processing: Swords of Legends Online
# now processing: Crash Bandicoot™ N. Sane Trilogy
# now processing: Stronghold Kingdoms
# now processing: Just Cause 4 Reloaded
# now processing: Escape Simulator
# now processing: Secret Neighbor: Hello Neighbor Multiplayer
# now processing: Machinarium
# now processing: Hell Yeah! Wrath of the Dead Rabbit
# now processing: Assassin's Creed 3
# now processing: Core Keeper
# now processing: Ironsight
# now processing: Skul: The Hero Slayer
# now processing: Mount and Blade: With Fire and Sword
# now processing: LEGO Star Wars : The Complete Saga
# now processing: Road Redemption
# now processing: BLEACH Brave Souls
# now processing: Contagion
# now processing: Scarlet Nexus
# now processing: Tropico 3
# now processing: Last Oasis
# now processing: Hardspace: Shipbreaker
# now processing: Police Simulator: Patrol Officers
# now processing: FINAL FANTASY IX
# now processing: Battlerite Royale
# now processing: Starship Troopers: Extermination
# now processing: KartRider: Drift
# now processing: DEATHLOOP
# now processing: Deponia
# now processing: ShellShock Live
# now processing: Sword Art Online: Fatal Bullet
# now processing: ClusterTruck
# now processing: Reflex
# now processing: Need for Speed™ Undercover
# now processing: Easy™ eSports
# now processing: Teeworlds
# now processing: Two Worlds Epic Edition
# now processing: Pirates, Vikings, and Knights II
# now processing: Card Hunter
# now processing: Murdered: Soul Suspect
# now processing: Wartales
# now processing: Satellite Reign
# now processing: BrickForce
# now processing: The Wind Road
# now processing: Iron Harvest
# now processing: Sniper Ghost Warrior 3
# now processing: Solasta: Crown of the Magister
# now processing: Galactic Civilizations III
# now processing: Dust: An Elysian Tail
# now processing: Resident Evil 0
# now processing: The Past Within
# now processing: Spelunky 2
# now processing: Darksiders Genesis
# now processing: LEGO® The Hobbit™
# now processing: Heaven Island - VR MMO
# now processing: Dorfromantik
# now processing: Destroy All Humans
# now processing: My Time At Portia
# now processing: SpaceChem
# now processing: Dawn of Man
# now processing: NBA 2K18
# now processing: FINAL FANTASY XII THE ZODIAC AGE
# now processing: Realm Grinder
# now processing: Dread Hunger
# now processing: GUNS UP!
# now processing: Timberborn
# now processing: The Last of Us™ Part I
# now processing: The Planet Crafter
# now processing: Dune: Spice Wars
# now processing: Legion TD 2 - Multiplayer Tower Defense
# now processing: Pixel Sketch
# now processing: Overcast - Walden and the Werewolf
# now processing: Far Cry Primal
# now processing: Forts
# now processing: F1® 2021
# now processing: Chinese Parents
# now processing: Max Payne
# now processing: Resident Evil 7 Teaser: Beginning Hour
# now processing: Empyrion - Galactic Survival
# now processing: Fallout 3
# now processing: Super Hexagon
# now processing: Dungeons & Dragons Online®
# now processing: Make it indie!
# now processing: Wo Long: Fallen Dynasty
# now processing: Nioh 2 - The Complete Edition
# now processing: Jet Set Radio
# now processing: Little Nightmares II
# now processing: X-Plane 11
# now processing: Islands of Nyne: Battle Royale
# now processing: Sniper Ghost Warrior
# now processing: HuniePop
# now processing: Nobody - The Turnaround
# now processing: Slime Rancher 2
# now processing: ANNO 2205
# now processing: Age of Wonders III
# now processing: Kingdom Rush - Tower Defense
# now processing: HUMANKIND™
# now processing: Injustice 2
# now processing: RADical ROACH Remastered
# now processing: TerraTech
# now processing: FINAL FANTASY XIII
# now processing: Terraformers
# now processing: Candle In Darkness
# now processing: LEGO® MARVEL's Avengers
# now processing: Antichamber
# now processing: Sally Face - Episode One
# now processing: VA-11 Hall-A: Cyberpunk Bartender Action
# now processing: Rogue Legacy 2
# now processing: WildStar
# now processing: BATTALION: Legacy
# now processing: The Callisto Protocol
# now processing: Kingdom: New Lands
# now processing: Dwarf Fortress
# now processing: Darwin Project
# now processing: ROMANCE OF THE THREE KINGDOMS XIV
# now processing: Dark Souls II
# now processing: Worm.is: The Game
# now processing: STAR WARS® THE FORCE UNLEASHED II
# now processing: Jurassic World Evolution 2
# now processing: F1® 2020
# now processing: Command & Conquer 3 Tiberium Wars™
# now processing: Cyber Hunter
# now processing: Gujian3(古剑奇谭三)
# now processing: My Beautiful Paper Smile
# now processing: Danganronpa V3: Killing Harmony
# now processing: Mr. Sun's Hatbox
# now processing: Songs of Conquest
# now processing: Ragnarok Online
# now processing: Learn to Fly 3
# now processing: Sonic Adventure 2
# now processing: Homeworld Remastered Collection
# now processing: House Party
# now processing: Overcooked
# now processing: A.V.A Global
# now processing: 20 Minutes Till Dawn
# now processing: Rocksmith® 2014 Edition - Remastered
# now processing: Ylands
# now processing: Will To Live Online
# now processing: Assassin's Creed® III Remastered
# now processing: Dreadnought
# now processing: Drug Dealer Simulator
# now processing: Leaf Blower Revolution - Idle Game
# now processing: DOOM 3
# now processing: Need for Speed™
# now processing: World of Warplanes
# now processing: McOsu
# now processing: Borderlands: Game of the Year Enhanced
# now processing: LEGO Harry Potter: Years 1-4
# now processing: Art of War: Red Tides
# now processing: Zero Hour
# now processing: TurnSignal
# now processing: XCOM®: Chimera Squad
# now processing: Dead Island - Definitive Edition
# now processing: Hydroneer
# now processing: LoveChoice
# now processing: STAR WARS™: Squadrons
# now processing: America's Army 3
# now processing: Golf It!
# now processing: Sometimes: Success Requires Sacrifice
# now processing: ESEA
# now processing: Risk of Rain Returns
# now processing: Planetbase
# now processing: TUNIC
# now processing: Himno
# now processing: Dead Island Riptide Definitive Edition
# now processing: Terra Incognita ~ Chapter One: The Descendant
# now processing: Heavy Metal Machines
# now processing: Jack Orlando: Directors Cut
# now processing: Bombergrounds: Reborn
# now processing: Turbo Pug DX
# now processing: Marvel's Avengers - The Definitive Edition
# now processing: DEATH STRANDING DIRECTOR'S CUT
# now processing: Forager
# now processing: Shadow Arena
# now processing: Torchlight III
# now processing: Clone Drone in the Danger Zone
# now processing: SAS: Zombie Assault 4
# now processing: Blood and Bacon
# now processing: Never Split the Party
# now processing: Tales of Maj'Eyal
# now processing: Diablo® IV
# now processing: RetroArch
# now processing: Metal Slug 3
# now processing: Pixel Strike 3D
# now processing: NEKOPARA Vol. 1
# now processing: Armored Warfare
# now processing: Aragami
# now processing: Danganronpa: Trigger Happy Havoc
# now processing: VTube Studio
# now processing: Supreme Commander
# now processing: Witch It
# now processing: Hello Neighbor 2 Alpha 1.5
# now processing: Battleborn
# now processing: 觅长生
# now processing: Worms Reloaded
# now processing: Bopl Battle
# now processing: OneShot
# now processing: Need for Speed™ Unbound
# now processing: Door Kickers: Action Squad
# now processing: Due Process
# now processing: Call of Cthulhu
# now processing: Chronicon
# now processing: Endless Sky
# now processing: Magic Lantern
# now processing: The Incredible Adventures of Van Helsing
# now processing: Call of Duty: Advanced Warfare - Gold Edition
# now processing: LEGO® Jurassic World™
# now processing: Strange Brigade
# now processing: Just Shapes & Beats
# now processing: SUPERHOT: MIND CONTROL DELETE
# now processing: Need for Speed™ Most Wanted
# now processing: Book of Demons
# now processing: ABZU
# now processing: Vainglory
# now processing: Plants vs. Zombies: Battle for Neighborville™
# ...
# now processing: System Shock: Enhanced Edition
# now processing: Hand of Fate 2
# now processing: Operation: Tango
# now processing: FORCED: Slightly Better Edition
# now processing: Hover
# now processing: PlanetSide Arena
# now processing: The LEGO® Movie Videogame
# now processing: Shroud of the Avatar: Forsaken Virtues
# now processing: Planets Under Attack
# now processing: The Deed
# now processing: Minicraft Shooter
# now processing: Community Garden
# now processing: Sword of the Stars: The Pit
# now processing: DEAD OR ALIVE 5 Last Round: Core Fighters
# now processing: Hot Lava
# now processing: Teslagrad
# now processing: Little Witch in the Woods
# now processing: MadOut2 BigCityOnline [CLOSED]
# now processing: Lunch Lady
# now processing: Big Ambitions
# now processing: For The King II
# now processing: SweatShop
# now processing: Anno 1404 History Edition
# now processing: SpiderHeck
# now processing: Reigns
# now processing: Botanicula
# now processing: Septerra Core
# now processing: CryoFall
# now processing: Strange Horticulture
# now processing: Little Witch Nobeta
# now processing: Luck be a Landlord
# now processing: BlazBlue Centralfiction
# now processing: Music Racer
# now processing: Wargame: AirLand Battle
# now processing: Guild Quest
# now processing: Warhammer® 40,000: Dawn Of War® - Winter Assault
# now processing: 再刷一把 PlayAgain
# now processing: Arma Reforger
# now processing: 35MM
# now processing: Paradise Killer
# now processing: Home Behind 2
# now processing: Tank Mechanic Simulator
# now processing: 8infinity
# now processing: The Wild Eight
# now processing: Cities XL Platinum
# now processing: Ragnarok Clicker
# now processing: Democracy 3
# now processing: Sonic the Hedgehog 4 - Episode I
# now processing: Gorky 17
# now processing: Metal War Online: Retribution
# now processing: WRC 7 FIA World Rally Championship
# now processing: Blasphemous 2
# now processing: Unturned - Dedicated Server
# now processing: Cube Racer
# now processing: Happy Room
# now processing: Downwell
# now processing: Scania Truck Driving Simulator
# now processing: Plebby Quest: The Crusades
# now processing: 懒人修仙传
# now processing: Cogs
# now processing: The Deer
# now processing: Clicker Guild
# now processing: The Wandering Village
# now processing: Shank 2
# now processing: Super Robot Wars 30
# now processing: Warriors of the Nile
# now processing: The Final Station
# now processing: Brigador: Up-Armored Edition
# now processing: Empires of the Undergrowth
# now processing: Sanctum
# now processing: Startopia
# now processing: The Room Two
# now processing: Dragon Saga
# now processing: Outlaws of the Old West
# now processing: Medieval Engineers
# now processing: Trolley Gold
# now processing: Anno Online
# now processing: Castlevania: Lords of Shadow 2
# now processing: Agents of Mayhem
# now processing: Loot Hero - DX
# now processing: Dungeon Siege III
# now processing: Warlock: Master of the Arcane
# now processing: Retro Run
# now processing: Toki Tori
# now processing: Istrolid
# now processing: Rock of Ages
# now processing: Terraforming Mars
# now processing: LEGO® Batman 2™ DC Super Heroes
# now processing: Dear Esther: Landmark Edition
# now processing: ANOTHER EDEN
# now processing: Hue
# now processing: Rebel Forces
# now processing: Liberated
# now processing: Throne of Lies: Medieval Politics
# now processing: Madden NFL 22
# now processing: PGA TOUR 2K21
# now processing: RPG Maker MV
# now processing: From Dust
# now processing: Hellish Quart
# now processing: The Incredible Adventures of Van Helsing III
# now processing: Deep Space Dash
# now processing: Earth 2160
# now processing: Samorost 3
# now processing: Rampage Knights
# now processing: Spore Creepy & Cute Parts Pack
# now processing: Dungeons
# now processing: HD Poker: Texas Hold'em
# now processing: Football, Tactics & Glory
# now processing: We Were Here Too
# now processing: In Sound Mind
# now processing: AI War: Fleet Command
# now processing: Batman: The Enemy Within - The Telltale Series
# now processing: Blade Symphony
# now processing: Endless World Idle RPG
# now processing: Until We Die
# now processing: Severed Steel
# now processing: Dungeons of Dredmor
# now processing: Construction Simulator
# now processing: desolate
# now processing: SimAirport
# now processing: Broken Sword 5: The Serpents Curse
# now processing: No Time To Explain Remastered
# now processing: Hunger Dungeon
# now processing: Red Trees Rail Co
# now processing: 河洛群俠傳 (Ho Tu Lo Shu ： The Books of Dragon)
# now processing: Thymesia
# now processing: Squishy the Suicidal Pig
# now processing: Pox Nora
# now processing: Dicey Dungeons
# now processing: The Basement Collection
# now processing: Manhunt
# now processing: King's Bounty: The Legend
# now processing: Train Sim World® 2020
# now processing: Nyasha
# now processing: Opus Magnum
# now processing: Tiny Tina's Assault on Dragon Keep: A Wonderlands One-shot Adventure
# now processing: Pseudoregalia
# now processing: Bridge Constructor Portal
# now processing: The Texas Chain Saw Massacre
# now processing: Drawful 2
# now processing: Little Misfortune
# now processing: King's Bounty: Armored Princess
# now processing: Sniper Elite: Nazi Zombie Army
# now processing: Europa Universalis III Complete
# now processing: Atomicrops
# now processing: LineVox
# now processing: Our Life: Beginnings & Always
# now processing: Memoir '44 Online
# now processing: Ravenous Devils
# now processing: Devil Daggers
# now processing: Puzzle Pirates
# now processing: antenna
# now processing: 雀姬/姫麻雀
# now processing: Budget Cuts
# now processing: Nemesis: Distress
# now processing: Firefighting Simulator - The Squad
# now processing: SKALD: Against the Black Priory
# now processing: Hammerfight
# now processing: American Fugitive
# now processing: Idle Big Devil
# now processing: Master Levels for Doom II
# now processing: Yi Xian: The Cultivation Card Game
# now processing: Curse of the Dead Gods
# now processing: Wurm Online
# now processing: Labyronia RPG
# now processing: Kivi, Toilet and Shotgun
# now processing: TDP4:Team Battle
# now processing: Lost Planet 3
# now processing: Rise to Ruins
# now processing: 1914: Prelude to Chaos
# now processing: Find Love or Die Trying
# now processing: IOSoccer
# now processing: Death and Taxes
# now processing: The Settlers Online
# now processing: Mad Games Tycoon 2
# now processing: X-Morph: Defense
# now processing: Stoneshard: Prologue
# now processing: SYNTHETIK: Arena
# now processing: Ruined King: A League of Legends Story™
# now processing: Primal Carnage
# now processing: The Episodic
# now processing: The Survivalists
# now processing: Black Skylands: Origins
# now processing: Blacksad - Under the Skin
# now processing: Champions of Regnum
# now processing: Stacking
# now processing: Farming Simulator 15
# now processing: The Turing Test
# now processing: Sid Meiers Railroads!
# now processing: Feign
# now processing: SpyParty
# now processing: Rebuild 3: Gangs of Deadsville
# now processing: Ben There, Dan That!
# now processing: WWE 2K18
# now processing: Sword With Sauce
# now processing: The Archotek Project
# now processing: Mr. Prepper: Prologue
# now processing: Lara Croft GO
# now processing: Hidden Folks
# now processing: Cook, Serve, Delicious! 2!!
# now processing: Sonic Frontiers
# now processing: Revolution Ace
# now processing: Lost
# now processing: Tails of Iron
# now processing: UFO: Afterlight
# now processing: Prince of Persia
# now processing: The Jackbox Party Pack 3
# now processing: METAL SLUG X
# now processing: The Underground Man
# now processing: Dis The Game
# now processing: Overcooked! All You Can Eat
# now processing: SCP: Escape Together
# now processing: Windward
# now processing: Carpe Diem
# now processing: Choo-Choo Charles
# now processing: Just Hero
# now processing: the static speaks my name
# now processing: Second Extinction
# now processing: Pixel Studio - pixel art editor
# now processing: Red Risk
# now processing: Shadow Warrior 3: Definitive Edition
# now processing: Shadows of Doubt
# now processing: Canyon Capers
# now processing: Emily is Away <3
# now processing: Steel Division: Normandy 44
# now processing: Alien Shooter 2 Reloaded
# now processing: Pathway
# now processing: Zup!
# now processing: Planescape: Torment: Enhanced Edition
# now processing: Freefall 3050AD
# now processing: Minecraft: Story Mode - A Telltale Games Series
# now processing: Dinosaur Hunt
# now processing: Cartel Tycoon
# now processing: Out There Somewhere
# now processing: Shadow of Azrael
# now processing: The Final Take®
# now processing: Color Symphony
# now processing: Runes of Magic
# now processing: Romance of the Three Kingdoms Maker
# now processing: Sakura Spirit
# now processing: From The Depths
# now processing: Intravenous
# now processing: The Bridge
# now processing: Polywar
# now processing: Apotheon
# now processing: RUSSIA BATTLEGROUNDS
# now processing: The Forgotten Ones
# now processing: CABAL Online
# now processing: Pentiment
# now processing: Madden NFL 21
# now processing: DuckTales: Remastered
# now processing: Drift Over Drive
# now processing: Waveform
# now processing: Undead Horde
# now processing: Painkiller Hell & Damnation
# now processing: Caster
# now processing: TIS-100
# now processing: Game of Thrones Winter is Coming
# now processing: Wandering Sword
# now processing: The Red Strings Club
# now processing: Drug Dealer Simulator: Free Sample
# now processing: The Culling Of The Cows
# now processing: Star Trek Timelines
# now processing: Capsized
# now processing: Monsters sandbox
# now processing: A Bird Story
# now processing: DOOM 64
# now processing: Project Highrise
# now processing: Tails Noir: Prologue
# now processing: *NEW* SCUFFED EPIC BHOP SIMULATOR 2023 (POG CHAMP)
# now processing: Wayfinder
# now processing: Russian SuperHero Dead Ivan
# now processing: Katamari Damacy REROLL
# now processing: Kindergarten
# now processing: CONFLICT OF NATIONS: WORLD WAR 3
# now processing: HOT WHEELS UNLEASHED™
# now processing: Icewind Dale: Enhanced Edition
# now processing: Bloons Adventure Time TD
# now processing: Might & Magic: Clash of Heroes
# now processing: Internet Cafe Simulator 2
# now processing: The Entropy Centre
# now processing: Everhood
# now processing: Gridiron
# now processing: Pacific Drive
# now processing: Startup Company
# now processing: The Darkside Detective
# now processing: Dead Age
# now processing: Space Haven
# now processing: Mortal Shell
# now processing: The Painscreek Killings
# now processing: Baldi's Basics Plus
# now processing: Order of Battle: World War II
# now processing: 16bit Trader
# now processing: The Dark Eye: Chains of Satinav
# now processing: Grimm's Hollow
# now processing: The Library of Babel
# now processing: Dreaming Sarah
# now processing: Mind Spheres
# now processing: Thief II: The Metal Age
# now processing: Planet's Edge
# now processing: The Dark Eye: Memoria
# now processing: Battlestations Pacific
# now processing: Ionball 2 : Ionstorm
# now processing: Star Saviors
# now processing: Survivalist
# now processing: Hades' Star
# now processing: Idle Slayer
# now processing: Material Girl
# now processing: Crazy Taxi™
# now processing: Necropolis: Brutal Edition
# now processing: SHENZHEN I/O
# now processing: Asteroid Bounty Hunter
# now processing: The Ship Single Player
# now processing: Milk outside a bag of milk outside a bag of milk
# now processing: HARDCORE MECHA
# now processing: Uebergame
# now processing: Rento Fortune: Online Dice Board Game (大富翁)
# now processing: Siege Survival: Gloria Victis Prologue
# now processing: Game of Thrones
# now processing: Fireworks Mania - An Explosive Simulator
# now processing: Owlboy
# now processing: Bad North: Jotunn Edition
# now processing: Sable
# now processing: Boring Man - Online Tactical Stickman Combat
# now processing: Yakuza 4 Remastered
# now processing: Quake 4
# now processing: The House of Da Vinci
# now processing: Strike.is: The Game
# now processing: Galactic Junk League
# now processing: Star Wars Jedi Knight: Mysteries of the Sith
# now processing: Bound By Flame
# now processing: Grow Home
# now processing: Bloons Monkey City
# now processing: Silent Storm Gold Edition
# now processing: Clownfield 2042
# now processing: KovaaK's
# now processing: Galaxy on Fire 2 ™ Full HD
# now processing: Carrier Command Gaea Mission
# now processing: Kentucky Route Zero: PC Edition
# now processing: Jalopy
# now processing: Sky Force Reloaded
# now processing: Robot Roller-Derby Disco Dodgeball
# now processing: Dead Rising 4
# now processing: Word Game: Episode 0
# now processing: Wildfrost
# now processing: Gas Guzzlers Extreme
# now processing: System Shock
# now processing: IL-2 Sturmovik™: 1946
# now processing: Intrusion 2
# now processing: The Howler
# now processing: Metal Gear Survive
# now processing: Space Rangers HD: A War Apart
# now processing: Death Road to Canada
# now processing: Sacred Gold
# now processing: Driver Booster for Steam
# now processing: The Slormancer
# now processing: Oddworld: New 'n' Tasty
# now processing: RUSSIAPHOBIA
# now processing: Aliens: Dark Descent
# now processing: The Banner Saga: Factions
# now processing: Void Bastards
# now processing: Tomb Raider V: Chronicles
# now processing: Need For Speed: Shift
# now processing: Vikings - Wolves of Midgard
# now processing: Contraband Police
# now processing: No-brainer Heroes 挂机吧！勇者
# now processing: Niche - a genetics survival game
# now processing: BADLAND: Game of the Year Edition
# now processing: And Yet It Moves
# now processing: WWE 2K22
# now processing: PRICE
# now processing: Metro Conflict: The Origin
# now processing: Among Ripples
# now processing: Narcissu 1st & 2nd
# now processing: Phoenix Point
# now processing: Potionomics
# now processing: Gloria Victis: Medieval MMORPG
# now processing: Citadel: Forged With Fire
# now processing: Ultimate General: Civil War
# now processing: Project Warlock
# now processing: Predator: Hunting Grounds
# now processing: The Lost Mythologies
# now processing: Long Live the Queen
# now processing: METAL SLUG
# now processing: Commandos: Beyond the Call of Duty
# now processing: Lone Leader
# now processing: Gravitas
# now processing: Unravel
# now processing: Agrou
# now processing: Heavenly Bodies
# now processing: Do Not Feed the Monkeys
# now processing: SteamWorld Dig 2
# now processing: Infested Planet
# now processing: High On Life
# now processing: Monster Prom 2: Monster Camp
# now processing: INDUSTRIA
# now processing: Hello Neighbor Alpha 2
# now processing: Super Bunny Man
# now processing: The Next Door
# now processing: The OPERATOR
# now processing: We Went Back
# now processing: GORN
# now processing: Sniper 3D Assassin: Free to Play
# now processing: Yet Another Zombie Survivors
# now processing: Observer: System Redux
# now processing: Mandagon
# now processing: Sid Meier's Ace Patrol
# now processing: Phoenotopia Awakening
# now processing: Tom Clancy's Ghost Recon: Future Soldier™
# now processing: Resident Evil Re:Verse
# now processing: N++ (NPLUSPLUS)
# now processing: The Quarry
# now processing: Despotism 3k
# now processing: ChilloutVR
# now processing: Anna's Quest
# now processing: Stratside
# now processing: The Iron Union
# now processing: Serious Sam: Siberian Mayhem
# now processing: StarDrive
# now processing: FURIDASHI: Drift Cyber Sport
# now processing: Castle Story
# now processing: Ancestors: The Humankind Odyssey
# now processing: You Have to Win the Game
# now processing: Black The Fall
# now processing: FINAL FANTASY VI
# now processing: Delver
# now processing: Nuclear Contingency
# now processing: Sea of Stars
# now processing: Edna & Harvey: Harvey's New Eyes
# now processing: Sniper Elite: Nazi Zombie Army 2
# now processing: Cryptark
# now processing: Pagan: Absent Gods
# now processing: Barn Finders
# now processing: Gorogoa
# now processing: High Profits
# now processing: Legacy of Kain: Defiance
# now processing: Haven
# now processing: Blazblue Entropy Effect
# now processing: Let's Draw
# now processing: The Riftbreaker: Prologue
# now processing: Iron Brigade
# now processing: Forgive me Father
# now processing: Amorous
# now processing: Lethal League Blaze
# now processing: The God's Chain
# now processing: CoH 2 - The Western Front Armies: Oberkommando West
# now processing: 20XX
# now processing: Cosmic Dust & Rust
# now processing: Planes, Bullets and Vodka
# now processing: BLACKTAIL
# now processing: The Jackbox Party Pack 2
# now processing: Battlefleet Gothic: Armada
# now processing: Occupy Mars: Prologue (2020)
# now processing: Fiesta Online
# now processing: Scythe: Digital Edition
# now processing: Wanba Warriors

# %%
# 12 months average price
# def monthly_avg_price(year, month, df):
#     monthprice = df[(df['timestamp'].dt.year == year) & (df['timestamp'].dt.month == month)]
#     if monthprice.empty:
#         return None
#     else:
#         current_index = monthprice.index[0]
#         start_price = df['current_price'].iloc[current_index-1]
#         return start_price

# monthly_avg_price(2021, 11, history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       8         start_price = df['current_price'].iloc[current_index-1]
#       9         return start_price
# ---> 11 monthly_avg_price(2021, 11, history)
#
# NameError: name 'history' is not defined

# %%
price_items = {
    'first_available_price': first_available_price,
    'regular_price_reduced': '', # boolean
    'price_reduced_date': '', # null if regular_price_reduced is false
    # 'first_available_date': '', # we already have it in the game info
    'historical_low': '',
    'historical_low_date': '',
    'historical_high_discount': '',
    'historical_high_discount_date': '',
    'first_discount': '',
    'first_discount_date': '',
    'last_discount': '',
    'last_discount_date': '',
    'average_duration_between_discounts_12months': '',
    'average_duration_of_discounts_12months': '',
    'avg_price': '',
    'avg_discount': '',

    

    # testing modules
    # time series analysis items
    'next_discount': '',
    # price decay is the average second derivative of a moving average of the price
    # we take 12 months of data, and calculate the moving average of the price
    # then we calculate the second derivative of the moving average
    # finally we average the second derivative over the 12 months
    'price_decay_rate': '', 

}

# get price history for a game

# %% [markdown]
# # DEV NOTEs

# %%
############# dev notes ####################



# Solution 02.
# Use result_type ='expand' when applying.

# def myfunc2(args):
#     e = args[0] + 2*args[1]
#     f = args[1]*args[2] + 1
#     g = args[2] + args[0] * args[1]
#     return [e, f, g]

# df[['e', 'f', 'g']] = df.apply(myfunc2, axis=1, result_type='expand')
# #                          x         y         z         e         f         g
# # ts                                                                          
# # 2014-05-15 10:38  0.120117  0.987305  0.116211  2.094727  1.114736  0.234803
# # 2014-05-15 10:39  0.117188  0.984375  0.122070  2.085938  1.120163  0.237427
# # 2014-05-15 10:40  0.119141  0.987305  0.119141  2.093751  1.117629  0.236770
# # 2014-05-15 10:41  0.116211  0.984375  0.120117  2.084961  1.118240  0.234512
# # 2014-05-15 10:42  0.119141  0.983398  0.118164  2.085937  1.116202  0.235327

# t2 = timeit.timeit(
#     "df.apply(myfunc2, axis=1, result_type='expand')",
#     globals=dict(df=df, myfunc2=myfunc2), number=10000)
# print(round(t2, 3), 'seconds')
# 9.907 seconds

# %% [markdown]
# ## to do
# - ~~I didn't take increasing prices into consideration, which shall be a rare case. But it should be tested.~~ After EDA, we noticed that many games choose to do a first week discount, which will lead to a increase in price.

# %% [markdown]
# ### idea: 等等党模拟器
# - 从数据中随机抽样，模拟等等党等多久能介到第一次打折？
#
# ### idea: 何时打折.jpg
# - 调用API，选取所有公司，基于数据给出合理的打折预估
