# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time
import tqdm
import seaborn as sns

# third-party imports
import numpy as np
import pandas as pd
import requests

# environment variables
from dotenv import load_dotenv
load_dotenv()
ANYDEALS_API_KEY = os.getenv("ANYDEAL_KEY")
# customisations - ensure tables show all columns
# pd.set_option("max_columns", 100)
print(ANYDEALS_API_KEY)
# Out:
# d0754faa36ea0d0d87c737908e13de1b56e857e5

# %%
df = pd.read_csv("price_items.csv")
df.head(10)
# Out:
#    Unnamed: 0                                    id                slug  \
# 0           0  018d937f-19a5-7057-bb6d-314d586e6dbc              dota-2
# 1           1  018d937f-7851-7004-b780-3f657a301f9a    counter-strike-2
# 2           2  018d937f-57ce-723f-b7e7-7c7b5df93471  pubg-battlegrounds
# 3           3  018d937f-50c1-7086-807c-e020c98c72b2            palworld
# 4           4  018d937e-fde4-72ff-a7af-45e4955a8dd6     team-fortress-2
# 5           5  018d937f-0ddf-7119-9337-aa96d8a36d39        apex-legends
# 6           6  018d937f-2f21-71cf-a59b-fbad13eddf95           new-world
# 7           7  018d983f-2710-722d-8efd-b8fc55b0ed23     call-of-duty--1
# 8           8  018d937f-03e2-7281-a961-037a2d279a92  grand-theft-auto-v
# 9           9  018d937f-2404-7297-93fb-94b54bdb74e5       left-4-dead-2
#
#                  title  type  mature  earlyAccess  achievements  tradingCards  \
# 0               Dota 2  game   False        False         False          True
# 1     Counter-Strike 2  game   False        False         False          True
# 2  PUBG: BATTLEGROUNDS  game   False        False          True         False
# 3             Palworld  game   False        False          True         False
# 4      Team Fortress 2  game   False        False          True          True
# 5        Apex Legends™  game   False        False          True          True
# 6            New World  game   False        False          True         False
# 7        Call of Duty®   NaN   False        False         False         False
# 8   Grand Theft Auto V  game   False        False         False         False
# 9        Left 4 Dead 2  game   False        False          True          True
#
#        appid  ... first_discount_date last_discount last_discount_date  \
# 0      570.0  ...          2012-11-22          75.0         2012-12-31
# 1      730.0  ...          2012-11-01          50.0         2018-06-21
# 2   578080.0  ...          2018-06-19          50.0         2021-02-11
# 3  1623730.0  ...          2024-01-19          25.0         2024-06-27
# 4      440.0  ...                 NaN           NaN                NaN
# 5  1172470.0  ...                 NaN           NaN                NaN
# 6  1063730.0  ...          2021-11-24          60.0         2024-06-27
# 7  1938090.0  ...                 NaN           NaN                NaN
# 8   271590.0  ...          2015-06-11          50.0         2020-12-22
# 9      550.0  ...          2012-10-25          90.0         2024-06-27
#
#                                discount_distribution  \
# 0  timestamp\n11    1\n12    3\nName: discount, d...
# 1  timestamp\n1      2\n2      2\n3      2\n6    ...
# 2  timestamp\n2     1\n4     1\n6     3\n7     2\...
# 3  timestamp\n1    1\n3    1\n4    1\n5    1\n6  ...
# 4                                                NaN
# 5                                                NaN
# 6  timestamp\n1     1\n3     2\n4     1\n5     1\...
# 7                                                NaN
# 8  timestamp\n1      1\n2      4\n3      5\n5    ...
# 9  timestamp\n1      1\n2      3\n3      4\n5    ...
#
#   average_duration_between_discounts_12months  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#   average_duration_of_discounts_12months avg_price avg_discount  \
# 0                                    NaN       NaN          NaN
# 1                                    NaN       NaN          NaN
# 2                                    NaN       NaN          NaN
# 3                                    NaN       NaN          NaN
# 4                                    NaN       NaN          NaN
# 5                                    NaN       NaN          NaN
# 6                                    NaN       NaN          NaN
# 7                                    NaN       NaN          NaN
# 8                                    NaN       NaN          NaN
# 9                                    NaN       NaN          NaN
#
#    next_discount price_decay_rate
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# 5            NaN              NaN
# 6            NaN              NaN
# 7            NaN              NaN
# 8            NaN              NaN
# 9            NaN              NaN
#
# [10 rows x 38 columns]

# %%
df['releaseDate'] = pd.to_datetime(df['releaseDate'])
df['first_discount_date'] = pd.to_datetime(df['first_discount_date'])
df['first_available_date'] = pd.to_datetime(df['first_available_date'])

# %%
print(df[df['id'] == '018d937f-12d5-7136-98e9-8e3f63b2048d'].to_string())
# Out:
#     Unnamed: 0                                    id                  slug                  title  type  mature  earlyAccess  achievements  tradingCards     appid                                                                                 tags releaseDate                                                                                                                                                               developers                                                                          publishers                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     reviews                                                 stats                                                         players                                                               urls  first_available_price regular_price_reduced price_reduced_date first_available_date last_available_date  historical_low historical_low_date  historical_high_discount historical_high_discount_date  first_discount first_discount_date  last_discount last_discount_date                                                                                                                                            discount_distribution  average_duration_between_discounts_12months  average_duration_of_discounts_12months  avg_price  avg_discount  next_discount  price_decay_rate
# 25          25  018d937f-12d5-7136-98e9-8e3f63b2048d  ark-survival-evolved  ARK: Survival Evolved  game   False        False          True         False  346110.0  ['Open World Survival Craft', 'Survival', 'Multiplayer', 'Open World', 'Dinosaurs']  2015-08-11  [{'id': 9713, 'name': 'Studio Wildcard'}, {'id': 2546, 'name': 'Virtual Basement LLC'}, {'id': 9715, 'name': 'Instinct Games'}, {'id': 9716, 'name': 'Efecto Studios'}]  [{'id': 9713, 'name': 'Studio Wildcard'}, {'id': 9714, 'name': 'Snail Games USA'}]  [{'score': 83, 'source': 'Steam', 'count': 516938, 'url': 'https://store.steampowered.com/app/346110/'}, {'score': 70, 'source': 'Metascore', 'count': 7, 'url': 'https://metacritic.com/game/ark-survival-evolved/critic-reviews/?platform=pc'}, {'score': 65, 'source': 'Metacritic User Score', 'count': 612, 'url': 'https://metacritic.com/game/ark-survival-evolved/user-reviews/?platform=pc'}, {'score': 61, 'source': 'OpenCritic', 'count': 53, 'url': 'https://opencritic.com/game/4657/ark-survival-evolved'}]  {'rank': 62, 'waitlisted': 5464, 'collected': 38923}  {'recent': 28371, 'day': 34529, 'week': 40767, 'peak': 229276}  {'game': 'https://isthereanydeal.com/game/ark-survival-evolved/'}                  29.99                  True         2017-07-05           2015-06-02          2024-02-11             0.0          2021-12-16                     100.0                    2022-06-12            17.0          2015-06-02           75.0         2023-06-29  timestamp\n1      4\n2      5\n3      5\n4      3\n5      3\n6     10\n7      4\n8      4\n9      2\n10     5\n11    11\n12     9\nName: discount, dtype: int64                                          NaN                                     NaN        NaN           NaN            NaN               NaN

# %%
df[df["first_available_price"].isna()]
# Out:
#       Unnamed: 0                                    id  \
# 4              4  018d937e-fde4-72ff-a7af-45e4955a8dd6
# 5              5  018d937f-0ddf-7119-9337-aa96d8a36d39
# 7              7  018d983f-2710-722d-8efd-b8fc55b0ed23
# 11            11  018d937f-50e3-70a2-9dc0-91a22a077ead
# 12            12  018d937e-e9b4-730e-bfaf-ed97c23a2848
# ...          ...                                   ...
# 2946        2973  018d937f-179a-7363-8612-8361000c5606
# 2949        2976  018d937f-440b-72ef-aee8-6df45dfe0e90
# 2952        2980  018d937f-29d3-7026-91ad-fd718b1e04da
# 2962        2990  018d96f1-a1a9-70ec-9c8a-06ef9eb86465
# 2963        2991  018d979a-4ad7-71e4-aecc-eb83bede66c6
#
#                            slug                         title  type  mature  \
# 4               team-fortress-2               Team Fortress 2  game   False
# 5                  apex-legends                 Apex Legends™  game   False
# 7               call-of-duty--1                 Call of Duty®   NaN   False
# 11                     lost-ark                      Lost Ark  game   False
# 12                     unturned                      Unturned  game   False
# ...                         ...                           ...   ...     ...
# 2946                      haven                         Haven  game   False
# 2949   the-riftbreaker-prologue     The Riftbreaker: Prologue  game   False
# 2952                    amorous                       Amorous  game    True
# 2962  occupy-mars-prologue-2020  Occupy Mars: Prologue (2020)  game   False
# 2963           fiesta-online--1                 Fiesta Online  game   False
#
#       earlyAccess  achievements  tradingCards      appid  ...  \
# 4           False          True          True      440.0  ...
# 5           False          True          True  1172470.0  ...
# 7           False         False         False  1938090.0  ...
# 11          False          True         False  1599340.0  ...
# 12          False          True          True   304930.0  ...
# ...           ...           ...           ...        ...  ...
# 2946        False          True         False   983970.0  ...
# 2949        False         False         False  1293860.0  ...
# 2952        False          True         False   778700.0  ...
# 2962        False         False         False  1310520.0  ...
# 2963        False         False         False   300970.0  ...
#
#      first_discount_date last_discount last_discount_date  \
# 4                    NaT           NaN                NaN
# 5                    NaT           NaN                NaN
# 7                    NaT           NaN                NaN
# 11                   NaT           NaN                NaN
# 12                   NaT           NaN                NaN
# ...                  ...           ...                ...
# 2946                 NaT           NaN                NaN
# 2949                 NaT           NaN                NaN
# 2952                 NaT           NaN                NaN
# 2962                 NaT           NaN                NaN
# 2963                 NaT           NaN                NaN
#
#      discount_distribution average_duration_between_discounts_12months  \
# 4                      NaN                                         NaN
# 5                      NaN                                         NaN
# 7                      NaN                                         NaN
# 11                     NaN                                         NaN
# 12                     NaN                                         NaN
# ...                    ...                                         ...
# 2946                   NaN                                         NaN
# 2949                   NaN                                         NaN
# 2952                   NaN                                         NaN
# 2962                   NaN                                         NaN
# 2963                   NaN                                         NaN
#
#      average_duration_of_discounts_12months avg_price avg_discount  \
# 4                                       NaN       NaN          NaN
# 5                                       NaN       NaN          NaN
# 7                                       NaN       NaN          NaN
# 11                                      NaN       NaN          NaN
# 12                                      NaN       NaN          NaN
# ...                                     ...       ...          ...
# 2946                                    NaN       NaN          NaN
# 2949                                    NaN       NaN          NaN
# 2952                                    NaN       NaN          NaN
# 2962                                    NaN       NaN          NaN
# 2963                                    NaN       NaN          NaN
#
#       next_discount price_decay_rate
# 4               NaN              NaN
# 5               NaN              NaN
# 7               NaN              NaN
# 11              NaN              NaN
# 12              NaN              NaN
# ...             ...              ...
# 2946            NaN              NaN
# 2949            NaN              NaN
# 2952            NaN              NaN
# 2962            NaN              NaN
# 2963            NaN              NaN
#
# [506 rows x 38 columns]

# %%
# if the first available price is missing, it means the item is always free

df.drop(df[df["first_available_price"].isna()].index, inplace=True)

# %%
df.shape
# Out:
# (2460, 38)

# %%
weird = df[df["first_available_date"] > df["releaseDate"]]
weird[["title", "releaseDate", "first_available_date"]]
# Out:
#                                 title releaseDate first_available_date
# 1                    Counter-Strike 2  2012-08-21           2012-11-01
# 9                       Left 4 Dead 2  2009-11-17           2012-10-25
# 17                           Terraria  2011-05-16           2012-09-09
# 19                        Garry's Mod  2006-11-29           2012-11-02
# 21    Tom Clancy's Rainbow Six® Siege  2015-01-05           2015-05-15
# ...                               ...         ...                  ...
# 2945         Legacy of Kain: Defiance  2003-12-16           2012-12-20
# 2947          Blazblue Entropy Effect  2023-08-15           2024-02-14
# 2950                     Iron Brigade  2012-08-13           2012-10-09
# 2958        Planes, Bullets and Vodka  2016-12-13           2016-12-14
# 2965                   Wanba Warriors  2020-03-25           2020-03-26
#
# [1013 rows x 3 columns]

# %%
# histogram of the release dates
sns.histplot(
    df["releaseDate"], 
    bins=50,
    kde=True
    )
# Out:
# <Axes: xlabel='releaseDate', ylabel='Count'>

# %%
games_released_post2013 = df[df["releaseDate"] > "2013-01-01"]
games_released_post2013['length_before_discount'] = games_released_post2013['first_discount_date'] - games_released_post2013['first_available_date']
games_released_post2013.shape
# Out:
# /var/folders/7m/bpynmdb95w587ztb6nlzcgg80000gn/T/ipykernel_14246/3652085102.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_released_post2013['length_before_discount'] = games_released_post2013['first_discount_date'] - games_released_post2013['first_available_date']
# (1873, 39)

# %%
# histogram of the first discounted
sns.histplot(
    games_released_post2013["first_discount"],
    bins=100,
    kde=True
    )
# Out:
# <Axes: xlabel='first_discount', ylabel='Count'>

# %%
games_released_post2013['length_before_discount'].describe()
# Out:
# count                           1843
# mean      69 days 17:31:40.596852957
# std      149 days 07:43:50.386504538
# min                  0 days 00:00:00
# 25%                  0 days 00:00:00
# 50%                  0 days 00:00:00
# 75%                 98 days 00:00:00
# max               2348 days 00:00:00
# Name: length_before_discount, dtype: object

# %%
games_released_post2013[games_released_post2013['length_before_discount'] == dt.timedelta(days=0)]
# Out:
#       Unnamed: 0                                    id  \
# 0              0  018d937f-19a5-7057-bb6d-314d586e6dbc
# 3              3  018d937f-50c1-7086-807c-e020c98c72b2
# 25            25  018d937f-12d5-7136-98e9-8e3f63b2048d
# 37            37  018d937e-fef7-7274-bbce-e7d155c3d2d1
# 38            38  018d937f-1212-7232-b23f-a046f6fd4a57
# ...          ...                                   ...
# 2957        2985  018d937e-ea89-7344-9ac3-14d06c9f92ae
# 2958        2986  018d937e-f976-721d-bebe-c2ab5833ff21
# 2959        2987  018d937f-50ea-72a6-9112-a81e293c5e13
# 2961        2989  018d937e-f973-71db-988b-4b9d2c183d55
# 2965        2993  018d937f-0e8d-7115-aaf8-578876bc1c80
#
#                            slug                       title     type  mature  \
# 0                        dota-2                      Dota 2     game   False
# 3                      palworld                    Palworld     game   False
# 25         ark-survival-evolved       ARK: Survival Evolved     game   False
# 37             dead-by-daylight            Dead by Daylight     game   False
# 38      the-witcher-3-wild-hunt    The Witcher 3: Wild Hunt  package   False
# ...                         ...                         ...      ...     ...
# 2957       cosmic-dust-and-rust          Cosmic Dust & Rust     game   False
# 2958   planes-bullets-and-vodka   Planes, Bullets and Vodka     game   False
# 2959                  blacktail                   BLACKTAIL     game   False
# 2961  battlefleet-gothic-armada  Battlefleet Gothic: Armada     game   False
# 2965             wanba-warriors              Wanba Warriors     game   False
#
#       earlyAccess  achievements  tradingCards      appid  ... last_discount  \
# 0           False         False          True      570.0  ...          75.0
# 3           False          True         False  1623730.0  ...          25.0
# 25          False          True         False   346110.0  ...          75.0
# 37          False          True          True   381210.0  ...          60.0
# 38          False          True          True   292030.0  ...          90.0
# ...           ...           ...           ...        ...  ...           ...
# 2957        False         False          True   473560.0  ...          50.0
# 2958        False          True          True   562360.0  ...          51.0
# 2959        False          True          True  1532690.0  ...          67.0
# 2961        False          True          True   363680.0  ...          85.0
# 2965        False         False          True  1021770.0  ...          70.0
#
#      last_discount_date                              discount_distribution  \
# 0            2012-12-31  timestamp\n11    1\n12    3\nName: discount, d...
# 3            2024-06-27  timestamp\n1    1\n3    1\n4    1\n5    1\n6  ...
# 25           2023-06-29  timestamp\n1      4\n2      5\n3      5\n4    ...
# 37           2024-07-25  timestamp\n1      5\n2      3\n3      7\n4    ...
# 38           2024-06-27  timestamp\n1      4\n2      8\n3      6\n4    ...
# ...                 ...                                                ...
# 2957         2024-07-29  timestamp\n1     5\n2     3\n3     4\n4     5\...
# 2958         2024-07-29  timestamp\n1      6\n2     11\n3      4\n4    ...
# 2959         2024-06-27  timestamp\n1     1\n2     1\n3     3\n4     1\...
# 2961         2024-06-27  timestamp\n1      5\n2      8\n3      6\n4    ...
# 2965         2024-07-29  timestamp\n1     2\n2     5\n3     4\n4     2\...
#
#      average_duration_between_discounts_12months  \
# 0                                            NaN
# 3                                            NaN
# 25                                           NaN
# 37                                           NaN
# 38                                           NaN
# ...                                          ...
# 2957                                         NaN
# 2958                                         NaN
# 2959                                         NaN
# 2961                                         NaN
# 2965                                         NaN
#
#      average_duration_of_discounts_12months avg_price avg_discount  \
# 0                                       NaN       NaN          NaN
# 3                                       NaN       NaN          NaN
# 25                                      NaN       NaN          NaN
# 37                                      NaN       NaN          NaN
# 38                                      NaN       NaN          NaN
# ...                                     ...       ...          ...
# 2957                                    NaN       NaN          NaN
# 2958                                    NaN       NaN          NaN
# 2959                                    NaN       NaN          NaN
# 2961                                    NaN       NaN          NaN
# 2965                                    NaN       NaN          NaN
#
#      next_discount  price_decay_rate length_before_discount
# 0              NaN               NaN                 0 days
# 3              NaN               NaN                 0 days
# 25             NaN               NaN                 0 days
# 37             NaN               NaN                 0 days
# 38             NaN               NaN                 0 days
# ...            ...               ...                    ...
# 2957           NaN               NaN                 0 days
# 2958           NaN               NaN                 0 days
# 2959           NaN               NaN                 0 days
# 2961           NaN               NaN                 0 days
# 2965           NaN               NaN                 0 days
#
# [974 rows x 39 columns]

# %%
# histogram of the length before discount
temp = games_released_post2013[(games_released_post2013['length_before_discount'] != dt.timedelta(days=0)) & (games_released_post2013['length_before_discount'] <= dt.timedelta(days=1000))]
sns.histplot(
    # temp['length_before_discount'].dt.days,
    games_released_post2013['length_before_discount'].dt.days,
    bins=100,
    kde=True
    )

# temp['length_before_discount'].describe()
games_released_post2013['length_before_discount'].describe()
games_released_post2013['Unnamed: 0'].describe()
# Out:
# count    1873.000000
# mean     1534.637480
# std       855.395455
# min         0.000000
# 25%       812.000000
# 50%      1559.000000
# 75%      2269.000000
# max      2993.000000
# Name: Unnamed: 0, dtype: float64

# %% [markdown]
# ## Suspected Eearly Access Games

# %%
EA_games = games_released_post2013[games_released_post2013['first_available_date'] < games_released_post2013['releaseDate']]
not_EA_games = games_released_post2013[games_released_post2013['first_available_date'] >= games_released_post2013['releaseDate']]
EA_games.head(10)
# Out:
#     Unnamed: 0                                    id                slug  \
# 0            0  018d937f-19a5-7057-bb6d-314d586e6dbc              dota-2
# 2            2  018d937f-57ce-723f-b7e7-7c7b5df93471  pubg-battlegrounds
# 6            6  018d937f-2f21-71cf-a59b-fbad13eddf95           new-world
# 8            8  018d937f-03e2-7281-a961-037a2d279a92  grand-theft-auto-v
# 10          10  018d937f-060f-705e-b364-8c5bba4d62f6                rust
# 14          14  018d937f-6ee4-73f5-858c-2fde3407462f        helldivers-2
# 16          16  018d937f-590c-728b-ac35-38bcff85f086          elden-ring
# 18          18  018d937f-29ff-7103-a625-0aa533390c1c          brawlhalla
# 20          20  018d9584-24d6-7010-b82b-df1f0b154cc7      baldurs-gate-3
# 23          23  018d937f-1783-708b-b28f-086097dcd3da    wallpaper-engine
#
#                   title  type  mature  earlyAccess  achievements  \
# 0                Dota 2  game   False        False         False
# 2   PUBG: BATTLEGROUNDS  game   False        False          True
# 6             New World  game   False        False          True
# 8    Grand Theft Auto V  game   False        False         False
# 10                 Rust  game   False        False          True
# 14         HELLDIVERS 2  game   False        False          True
# 16           Elden Ring  game   False        False          True
# 18           Brawlhalla  game   False        False          True
# 20      Baldur's Gate 3  game   False        False          True
# 23     Wallpaper Engine   NaN   False        False          True
#
#     tradingCards      appid  ... last_discount last_discount_date  \
# 0           True      570.0  ...          75.0         2012-12-31
# 2          False   578080.0  ...          50.0         2021-02-11
# 6          False  1063730.0  ...          60.0         2024-06-27
# 8          False   271590.0  ...          50.0         2020-12-22
# 10          True   252490.0  ...          50.0         2024-07-15
# 14         False   553850.0  ...           NaN                NaN
# 16          True  1245620.0  ...          30.0         2024-06-27
# 18          True   291550.0  ...           NaN                NaN
# 20         False  1086940.0  ...          20.0         2024-06-27
# 23          True   431960.0  ...          10.0         2021-02-08
#
#                                 discount_distribution  \
# 0   timestamp\n11    1\n12    3\nName: discount, d...
# 2   timestamp\n2     1\n4     1\n6     3\n7     2\...
# 6   timestamp\n1     1\n3     2\n4     1\n5     1\...
# 8   timestamp\n1      1\n2      4\n3      5\n5    ...
# 10  timestamp\n1      3\n2      3\n3      3\n4    ...
# 14                                                NaN
# 16  timestamp\n6     2\n10    1\n12    2\nName: di...
# 18                                                NaN
# 20  timestamp\n3     1\n5     1\n6     1\n12    1\...
# 23    timestamp\n2    1\nName: discount, dtype: int64
#
#    average_duration_between_discounts_12months  \
# 0                                          NaN
# 2                                          NaN
# 6                                          NaN
# 8                                          NaN
# 10                                         NaN
# 14                                         NaN
# 16                                         NaN
# 18                                         NaN
# 20                                         NaN
# 23                                         NaN
#
#    average_duration_of_discounts_12months avg_price avg_discount  \
# 0                                     NaN       NaN          NaN
# 2                                     NaN       NaN          NaN
# 6                                     NaN       NaN          NaN
# 8                                     NaN       NaN          NaN
# 10                                    NaN       NaN          NaN
# 14                                    NaN       NaN          NaN
# 16                                    NaN       NaN          NaN
# 18                                    NaN       NaN          NaN
# 20                                    NaN       NaN          NaN
# 23                                    NaN       NaN          NaN
#
#    next_discount  price_decay_rate length_before_discount
# 0            NaN               NaN                 0 days
# 2            NaN               NaN               452 days
# 6            NaN               NaN               713 days
# 8            NaN               NaN               145 days
# 10           NaN               NaN               711 days
# 14           NaN               NaN                    NaT
# 16           NaN               NaN               413 days
# 18           NaN               NaN                    NaT
# 20           NaN               NaN              1171 days
# 23           NaN               NaN              1581 days
#
# [10 rows x 39 columns]

# %%
# histogram of the the length before discount for EA games and not EA games
sns.histplot(
    EA_games['length_before_discount'].dt.days,
    bins=100,
    kde=True,
    stat="density",
    color="red"
    )
sns.histplot(
    not_EA_games['length_before_discount'].dt.days,
    bins=100,
    kde=True,
    stat="density",
    color="blue"
    )
# Out:
# <Axes: xlabel='length_before_discount', ylabel='Density'>

# %%
comparison = pd.DataFrame()
comparison["EA"] = EA_games['length_before_discount'].describe()
comparison["not EA"] = not_EA_games['length_before_discount'].describe()
comparison['EA_ranks'] = EA_games['Unnamed: 0'].describe()
comparison['not EA_ranks'] = not_EA_games['Unnamed: 0'].describe()

comparison
# Out:
#                                 EA                       not EA     EA_ranks  \
# count                          772                         1071   788.000000
# mean   108 days 09:49:25.803108808   41 days 20:23:31.764705882  1332.440355
# std    184 days 18:24:20.826275602  109 days 05:08:47.364456988   847.360485
# min                0 days 00:00:00              0 days 00:00:00     0.000000
# 25%                0 days 00:00:00              0 days 00:00:00   571.750000
# 50%               70 days 00:00:00              0 days 00:00:00  1242.000000
# 75%              148 days 06:00:00             52 days 12:00:00  2000.500000
# max             2348 days 00:00:00           1600 days 00:00:00  2992.000000
#
#        not EA_ranks
# count   1085.000000
# mean    1681.486636
# std      831.267098
# min        3.000000
# 25%     1001.000000
# 50%     1754.000000
# 75%     2404.000000
# max     2993.000000

# %%
EA_games.loc[:,'possible_EA_duration'] = EA_games['releaseDate'] - EA_games['first_available_date']
EA_games['possible_EA_duration'].describe()
# Out:
# /var/folders/7m/bpynmdb95w587ztb6nlzcgg80000gn/T/ipykernel_14246/631531577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EA_games.loc[:,'possible_EA_duration'] = EA_games['releaseDate'] - EA_games['first_available_date']
# count                            788
# mean     284 days 20:55:25.888324872
# std      457 days 15:12:53.894009496
# min                  1 days 00:00:00
# 25%                 41 days 00:00:00
# 50%                101 days 12:00:00
# 75%                309 days 06:00:00
# max               3894 days 00:00:00
# Name: possible_EA_duration, dtype: object

# %%
# histogram of the possible EA duration
sns.histplot(
    EA_games['possible_EA_duration'].dt.days,
    bins=100,
    kde=True,
    stat="density",
    color="red"
    )
# Out:
# <Axes: xlabel='possible_EA_duration', ylabel='Density'>

# %%
EA_games[EA_games['possible_EA_duration'] <= dt.timedelta(days=30)]
# Out:
#       Unnamed: 0                                    id  \
# 28            28  018d937f-2947-726f-ab1e-7bf149096fff
# 36            36  018d937f-4640-728f-9dee-ff5702d93303
# 58            58  018d937e-fd94-7238-a99b-14457502670c
# 84            84  018d937e-ff65-73f8-8d14-410ce85fa304
# 93            93  018d937e-f840-7073-871c-bd42fd7d4bdf
# ...          ...                                   ...
# 2840        2866  018d937f-1b07-7082-b6dc-631d06af0ddd
# 2860        2886  018d937f-1981-7124-9934-c099cd14f97e
# 2866        2892  018d937e-f849-700a-9462-5166d1c08f96
# 2927        2954  018d937f-5c47-73f7-b047-1e436148ec4a
# 2939        2966  018d937f-2a0b-7215-8390-ed28c0b9f40e
#
#                                  slug                             title  type  \
# 28                           payday-2                          PAYDAY 2  game
# 36                          fall-guys                         Fall Guys  game
# 58               monster-hunter-world             Monster Hunter: World  game
# 84                    cities-skylines                  Cities: Skylines  game
# 93                           nba-2k20                          NBA 2K20  game
# ...                               ...                               ...   ...
# 2840                   bound-by-flame                    Bound By Flame  game
# 2860               metal-gear-survive                Metal Gear Survive  game
# 2866             oddworld-new-n-tasty           Oddworld: New 'n' Tasty  game
# 2927      serious-sam-siberian-mayhem      Serious Sam: Siberian Mayhem  game
# 2939  sniper-elite-nazi-zombie-army-2  Sniper Elite: Nazi Zombie Army 2  game
#
#       mature  earlyAccess  achievements  tradingCards      appid  ...  \
# 28     False        False          True          True   218620.0  ...
# 36     False        False          True         False  1097150.0  ...
# 58     False        False          True          True   582010.0  ...
# 84     False        False          True          True   255710.0  ...
# 93     False        False          True         False  1089350.0  ...
# ...      ...          ...           ...           ...        ...  ...
# 2840   False        False          True          True   243930.0  ...
# 2860   False        False          True         False   543900.0  ...
# 2866   False        False          True          True   314660.0  ...
# 2927   False        False          True          True  1792250.0  ...
# 2939   False        False          True          True   247910.0  ...
#
#      last_discount_date                              discount_distribution  \
# 28           2024-07-15  timestamp\n1      6\n2      5\n3      5\n4    ...
# 36           2021-02-11  timestamp\n2     1\n11    1\n12    2\nName: di...
# 58           2024-06-27  timestamp\n1      4\n2      4\n3      2\n4    ...
# 84           2024-06-27  timestamp\n1      4\n2     10\n3      6\n4    ...
# 93           2020-08-18  timestamp\n1     1\n2     1\n3     2\n5     1\...
# ...                 ...                                                ...
# 2840         2024-06-27  timestamp\n1      4\n2      6\n3      3\n4    ...
# 2860         2024-06-27  timestamp\n1     3\n2     2\n3     2\n4     5\...
# 2866         2024-06-27  timestamp\n1      2\n2      4\n3      2\n4    ...
# 2927         2024-06-27  timestamp\n1     3\n2     1\n3     2\n4     2\...
# 2939         2024-06-27  timestamp\n1      5\n2      9\n3      3\n4    ...
#
#      average_duration_between_discounts_12months  \
# 28                                           NaN
# 36                                           NaN
# 58                                           NaN
# 84                                           NaN
# 93                                           NaN
# ...                                          ...
# 2840                                         NaN
# 2860                                         NaN
# 2866                                         NaN
# 2927                                         NaN
# 2939                                         NaN
#
#      average_duration_of_discounts_12months avg_price avg_discount  \
# 28                                      NaN       NaN          NaN
# 36                                      NaN       NaN          NaN
# 58                                      NaN       NaN          NaN
# 84                                      NaN       NaN          NaN
# 93                                      NaN       NaN          NaN
# ...                                     ...       ...          ...
# 2840                                    NaN       NaN          NaN
# 2860                                    NaN       NaN          NaN
# 2866                                    NaN       NaN          NaN
# 2927                                    NaN       NaN          NaN
# 2939                                    NaN       NaN          NaN
#
#      next_discount price_decay_rate  length_before_discount  \
# 28             NaN              NaN                 75 days
# 36             NaN              NaN                137 days
# 58             NaN              NaN                 87 days
# 84             NaN              NaN                120 days
# 93             NaN              NaN                 62 days
# ...            ...              ...                     ...
# 2840           NaN              NaN                  0 days
# 2860           NaN              NaN                156 days
# 2866           NaN              NaN                  0 days
# 2927           NaN              NaN                  0 days
# 2939           NaN              NaN                  0 days
#
#      possible_EA_duration
# 28                 9 days
# 36                23 days
# 58                30 days
# 84                27 days
# 93                17 days
# ...                   ...
# 2840              15 days
# 2860              13 days
# 2866              23 days
# 2927              15 days
# 2939              13 days
#
# [164 rows x 40 columns]
